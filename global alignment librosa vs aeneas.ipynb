# %%
import math
import numpy
import librosa
from enum import Enum
import struct

#from scipy.spatial.distance import cdist

NUM_MFCC = 13
NUM_MELS = 40
SAMPLE_RATE = 16000
NUM_FFT = 2048
FFT_ORDER  = 512
LOWER_FREQ = 133.333300
HIGHEST_FREQ = 6855.497600
WINDOW_LENGTH = int(0.10 * SAMPLE_RATE)
HOP_LENGTH = int(0.04 * SAMPLE_RATE)
EMPHASIS_FACTOR = 0.97
DTW_MARGIN = 60

class AlignmentAlgorithm(Enum):
    DTW_STRIPE = "DTW_STRIPE"
    DTW_EXACT = "DTW_EXACT"

DTW_ALGORITHM = AlignmentAlgorithm.DTW_EXACT


"""
This module contains the implementation
of dynamic time warping (DTW) algorithms
to align two audio waves, represented by their
Mel-frequency cepstral coefficients (MFCCs).

This module contains the following classes:

* :class:`~aeneas.dtw.DTWAlgorithm`,
  an enumeration of the available algorithms;
* :class:`~aeneas.dtw.DTWAligner`,
  the actual wave aligner;
* :class:`~aeneas.dtw.DTWExact`,
  a DTW aligner implementing the exact (full) DTW algorithm;
* :class:`~aeneas.dtw.DTWStripe`,
  a DTW aligner implementing the Sachoe-Chiba band heuristic.

To align two wave files:

1. build an :class:`~aeneas.dtw.DTWAligner` object,
   passing in the constructor
   the paths of the two wave files
   or their MFCC representations;
2. call :func:`~aeneas.dtw.DTWAligner.compute_path`
   to compute the min cost path between
   the MFCC representations of the two wave files.

.. warning:: This module might be refactored in a future version
"""

class aeneas_dtw():

    def __init__(
        self,
        params, q_audio, r_audio
    ):
        self.params = params
        self.query_audio = q_audio 
        self.ref_audio = r_audio
        self._setup_dtw()

    def compute_accumulated_cost_matrix(self):
        """
        Compute the accumulated cost matrix, and return it.

        Return ``None`` if the accumulated cost matrix cannot be computed
        because one of the two waves is empty after masking (if requested).

        :rtype: :class:`numpy.ndarray` (2D)
        :raises: RuntimeError: if both the C extension and
                               the pure Python code did not succeed.

        .. versionadded:: 1.2.0
        """
        if self.dtw is None:
            assert 0
        return self.dtw.compute_accumulated_cost_matrix()

    def compute_path(self):
        """
        Compute the min cost path between the two waves, and return it.

        Return the computed path as a tuple with two elements,
        each being a :class:`numpy.ndarray` (1D) of ``int`` indices: ::

        ([r_1, r_2, ..., r_k], [s_1, s_2, ..., s_k])

        where ``r_i`` are the indices in the real wave
        and ``s_i`` are the indices in the synthesized wave,
        and ``k`` is the length of the min cost path.

        Return ``None`` if the accumulated cost matrix cannot be computed
        because one of the two waves is empty after masking (if requested).

        :rtype: tuple (see above)
        :raises: RuntimeError: if both the C extension and
                               the pure Python code did not succeed.
        """
        wave_path = self.dtw.compute_path()
        return wave_path    

    def _setup_dtw(self):
        """
        Set the DTW object up.
        """

        # setup
        window_shift = self.params.hop_length/self.params.sr
        delta = int(2 * self.params.dtw_margin / window_shift)
        
        # set the selected algorithm
        if self.params.dtw_algorithm == AlignmentAlgorithm.DTW_EXACT:
            self.dtw = DTWExact(
                self.query_audio.mfcc,
                self.ref_audio.mfcc                
            )
        else:
            self.dtw = DTWStripe(
                self.query_audio.mfcc,
                self.ref_audio.mfcc,
                delta
            )

class DTWStripe():

    def __init__(self, m1, m2, delta):
        self.m1 = m1
        self.m2 = m2
        self.delta = delta

    def compute_path(self):
        try:
            cost_matrix, centers = self._compute_cost_matrix()
            accumulated_cost_matrix = self._compute_accumulated_cost_matrix(cost_matrix, centers)
            best_path = self._compute_best_path(accumulated_cost_matrix, centers)
            return best_path
        except Exception as exc:
            print("An unexpected error occurred while running pure Python code", exc, False, None)
        return (False, None)

    def _compute_cost_matrix(self):
        # discard first MFCC component
        mfcc1 = self.m1[1:, :]
        mfcc2 = self.m2[1:, :]
        norm2_1 = numpy.sqrt(numpy.sum(mfcc1 ** 2, 0))
        norm2_2 = numpy.sqrt(numpy.sum(mfcc2 ** 2, 0))
        n = mfcc1.shape[1]
        m = mfcc2.shape[1]
        delta = self.delta
        if delta > m:
            delta = m
        cost_matrix = numpy.zeros((n, delta))
        centers = numpy.zeros(n, dtype=int)
        for i in range(n):
            # center j at row i
            center_j = (m * i) // n
            # COMMENTED self.log([u"Center at row %d is %d", i, center_j])
            range_start = max(0, center_j - (delta // 2))
            range_end = range_start + delta
            if range_end > m:
                range_end = m
                range_start = range_end - delta
            centers[i] = range_start
            # COMMENTED self.log([u"Range at row %d is %d %d", i, range_start, range_end])
            for j in range(range_start, range_end):
                tmp = mfcc1[:, i].transpose().dot(mfcc2[:, j])
                tmp /= norm2_1[i] * norm2_2[j]
                cost_matrix[i][j - range_start] = 1 - tmp
        return (cost_matrix, centers)

    def _compute_accumulated_cost_matrix(self, cost_matrix, centers):
        # create accumulated cost matrix
        #
        # a[i][j] = c[i][j] + min(c[i-1][j-1], c[i-1][j], c[i][j-1])
        #
        return self._compute_acm_in_place(cost_matrix, centers)

    def _compute_acm_in_place(self, cost_matrix, centers):
        n, delta = cost_matrix.shape
        current_row = numpy.copy(cost_matrix[0, :])
        # COMMENTED cost_matrix[0][0] = current_row[0]
        for j in range(1, delta):
            cost_matrix[0][j] = current_row[j] + cost_matrix[0][j - 1]
        # fill table
        for i in range(1, n):
            current_row = numpy.copy(cost_matrix[i, :])
            offset = centers[i] - centers[i - 1]
            for j in range(delta):
                cost0 = numpy.inf
                if (j + offset) < delta:
                    cost0 = cost_matrix[i - 1][j + offset]
                cost1 = numpy.inf
                if j > 0:
                    cost1 = cost_matrix[i][j - 1]
                cost2 = numpy.inf
                if ((j + offset - 1) < delta) and ((j + offset - 1) >= 0):
                    cost2 = cost_matrix[i - 1][j + offset - 1]
                cost_matrix[i][j] = current_row[j] + min(cost0, cost1, cost2)
        return cost_matrix

    def _compute_best_path(self, acc_matrix, centers):
        # get dimensions
        n, delta = acc_matrix.shape
        i = n - 1
        j = delta - 1 + centers[i]
        path = [(i, j)]
        # compute best (min cost) path
        while (i > 0) or (j > 0):
            if i == 0:
                path.append((0, j - 1))
                j -= 1
            elif j == 0:
                path.append((i - 1, 0))
                i -= 1
            else:
                offset = centers[i] - centers[i - 1]
                r_j = j - centers[i]
                cost0 = numpy.inf
                if (r_j + offset) < delta:
                    cost0 = acc_matrix[i - 1][r_j + offset]
                cost1 = numpy.inf
                if r_j > 0:
                    cost1 = acc_matrix[i][r_j - 1]
                cost2 = numpy.inf
                if (r_j > 0) and ((r_j + offset - 1) < delta) and ((r_j + offset - 1) >= 0):
                    cost2 = acc_matrix[i - 1][r_j + offset - 1]
                costs = [
                    cost0,
                    cost1,
                    cost2
                ]
                moves = [
                    (i - 1, j),
                    (i, j - 1),
                    (i - 1, j - 1)
                ]
                min_cost = numpy.argmin(costs)
                # COMMENTED self.log([u"Selected min cost move %d", min_cost])
                min_move = moves[min_cost]
                path.append(min_move)
                i, j = min_move
        return path

class DTWExact():

    def __init__(self, m1, m2):
        self.m1 = m1
        self.m2 = m2

    def compute_accumulated_cost_matrix(self):
        cost_matrix = self._compute_cost_matrix()
        accumulated_cost_matrix = self._compute_accumulated_cost_matrix(cost_matrix)
        return accumulated_cost_matrix

    def compute_path(self):
        accumulated_cost_matrix = self.compute_accumulated_cost_matrix()
        best_path = self._compute_best_path(accumulated_cost_matrix)
        return best_path

    def _compute_cost_matrix(self):
        # discard first MFCC component
        mfcc1 = self.m1[1:, :]
        mfcc2 = self.m2[1:, :]
        norm2_1 = numpy.sqrt(numpy.sum(mfcc1 ** 2, 0))
        norm2_2 = numpy.sqrt(numpy.sum(mfcc2 ** 2, 0))
        # compute dot product
        cost_matrix = mfcc1.transpose().dot(mfcc2)
        # normalize
        norm_matrix = numpy.outer(norm2_1, norm2_2)
        cost_matrix = 1 - (cost_matrix / norm_matrix)
        return cost_matrix

    def _compute_accumulated_cost_matrix(self, cost_matrix):
        # create accumulated cost matrix
        #
        # a[i][j] = c[i][j] + min(c[i-1][j-1], c[i-1][j], c[i][j-1])
        #
        return self._compute_acm_in_place(cost_matrix)

    def _compute_acm_in_place(self, cost_matrix):
        n, m = cost_matrix.shape
        current_row = numpy.copy(cost_matrix[0, :])
        # COMMENTED cost_matrix[0][0] = current_row[0]
        for j in range(1, m):
            cost_matrix[0][j] = current_row[j] + cost_matrix[0][j - 1]
        for i in range(1, n):
            current_row = numpy.copy(cost_matrix[i, :])
            cost_matrix[i][0] = cost_matrix[i - 1][0] + current_row[0]
            for j in range(1, m):
                cost_matrix[i][j] = current_row[j] + min(
                    cost_matrix[i - 1][j],
                    cost_matrix[i][j - 1],
                    cost_matrix[i - 1][j - 1]
                )
        return cost_matrix

    def _compute_best_path(self, acc_matrix):
        # get dimensions
        n, m = acc_matrix.shape
        i = n - 1
        j = m - 1
        path = [(i, j)]
        # compute best (min cost) path
        while (i > 0) or (j > 0):
            if i == 0:
                path.append((0, j - 1))
                j -= 1
            elif j == 0:
                path.append((i - 1, 0))
                i -= 1
            else:
                costs = [
                    acc_matrix[i - 1][j],
                    acc_matrix[i][j - 1],
                    acc_matrix[i - 1][j - 1]
                ]
                moves = [
                    (i - 1, j),
                    (i, j - 1),
                    (i - 1, j - 1)
                ]
                min_cost = numpy.argmin(costs)
                # COMMENTED self.log([u"Selected min cost move %d", min_cost])
                min_move = moves[min_cost]
                path.append(min_move)
                i, j = min_move
        return path

class aeneas_mfcc():
    """
    A class for computing Mel-frequency cepstral coefficients (MFCCs).
    """

    CUTOFF = 0.00001
    """ Cut-off threshold """

    MEL_10 = 2595.0
    """ Base Mel frequency """

    TAG = u"MFCC"

    def __init__(self, params):

        # store parameters in local attributes
        self.filter_bank_size = params.n_mel
        self.mfcc_size = params.n_mfcc
        self.fft_order = params.fft_order
        self.lower_frequency = params.low_freq
        self.upper_frequency = params.high_freq
        self.emphasis_factor = params.emphasis_factor
        self.window_length = params.win_length/params.sr
        self.window_shift = params.hop_length/params.sr

        # initialize DCT matrix
        self._create_dct_matrix()

        # initialized later by compute_from_data()
        self.data = None
        self.sample_rate = None
        self.filters = None
        self.hamming_window = None

    @classmethod
    def _hz2mel(cls, frequency):
        """
        Convert the given frequency in Hz to the Mel scale.

        :param float frequency: the Hz frequency to convert
        :rtype: float
        """
        return cls.MEL_10 * math.log10(1.0 + (frequency / 700.0))

    @classmethod
    def _mel2hz(cls, mel):
        """
        Convert the given Mel value to Hz frequency.

        :param float mel: the Mel value to convert
        :rtype: float
        """
        return 700.0 * (10 ** (mel / cls.MEL_10) - 1)

    def _create_dct_matrix(self):
        """
        Create the not-quite-DCT matrix as used by Sphinx,
        and store it in ```self.s2dct```.
        """
        self.s2dct = numpy.zeros((self.mfcc_size, self.filter_bank_size))
        for i in range(0, self.mfcc_size):
            freq = numpy.pi * float(i) / self.filter_bank_size
            self.s2dct[i] = numpy.cos(freq * numpy.arange(0.5, 0.5 + self.filter_bank_size, 1.0, 'float64'))
        self.s2dct[:, 0] *= 0.5
        self.s2dct = self.s2dct.transpose()

    def _create_mel_filter_bank(self):
        """
        Create the Mel filter bank,
        and store it in ``self.filters``.

        Note that it is a function of the audio sample rate,
        so it cannot be created in the class initializer,
        but only later in :func:`aeneas.mfcc.MFCC.compute_from_data`.
        """
        self.filters = numpy.zeros((1 + (self.fft_order // 2), self.filter_bank_size), 'd')
        dfreq = float(self.sample_rate) / self.fft_order
        nyquist_frequency = self.sample_rate / 2
        if self.upper_frequency > nyquist_frequency:
            self.log_exc(u"Upper frequency %f exceeds Nyquist frequency %f" % (self.upper_frequency, nyquist_frequency), None, True, ValueError)
        melmax = aeneas_mfcc._hz2mel(self.upper_frequency)
        melmin = aeneas_mfcc._hz2mel(self.lower_frequency)
        dmelbw = (melmax - melmin) / (self.filter_bank_size + 1)
        filt_edge = aeneas_mfcc._mel2hz(melmin + dmelbw * numpy.arange(self.filter_bank_size + 2, dtype='d'))

        # TODO can this code be written more numpy-style?
        #      (the performance loss is negligible, it is just ugly to see)
        for whichfilt in range(0, self.filter_bank_size):
            # int() casts to native int instead of working with numpy.float64
            leftfr = int(round(filt_edge[whichfilt] / dfreq))
            centerfr = int(round(filt_edge[whichfilt + 1] / dfreq))
            rightfr = int(round(filt_edge[whichfilt + 2] / dfreq))
            fwidth = (rightfr - leftfr) * dfreq
            height = 2.0 / fwidth
            if centerfr != leftfr:
                leftslope = height / (centerfr - leftfr)
            else:
                leftslope = 0
            freq = leftfr + 1
            while freq < centerfr:
                self.filters[freq, whichfilt] = (freq - leftfr) * leftslope
                freq = freq + 1
            # the next if should always be true!
            if freq == centerfr:
                self.filters[freq, whichfilt] = height
                freq = freq + 1
            if centerfr != rightfr:
                rightslope = height / (centerfr - rightfr)
            while freq < rightfr:
                self.filters[freq, whichfilt] = (freq - rightfr) * rightslope
                freq = freq + 1

    def _pre_emphasis(self):
        """
        Pre-emphasize the entire signal at once by self.emphasis_factor,
        overwriting ``self.data``.
        """
        self.data = numpy.append(self.data[0], self.data[1:] - self.emphasis_factor * self.data[:-1])

    def compute_from_data(self, data, sample_rate):
        """
        Compute MFCCs for the given audio data.

        The audio data must be a 1D :class:`numpy.ndarray`,
        that is, it must represent a monoaural (single channel)
        array of ``float64`` values in ``[-1.0, 1.0]``.

        :param data: the audio data
        :type  data: :class:`numpy.ndarray` (1D)
        :param int sample_rate: the sample rate of the audio data, in samples/s (Hz)
        :raises: ValueError: if the data is not a 1D :class:`numpy.ndarray` (i.e., not mono),
                             or if the data is empty
        :raises: ValueError: if the upper frequency defined in the ``rconf`` is
                             larger than the Nyquist frequenct (i.e., half of ``sample_rate``)
        """
        def _process_frame(self, frame):
            """
            Process each frame, returning the log(power()) of it.
            """
            # apply Hamming window
            frame *= self.hamming_window
            # compute RFFT
            fft = numpy.fft.rfft(frame, self.fft_order)
            # equivalent to power = fft.real * fft.real + fft.imag * fft.imag
            power = numpy.square(numpy.absolute(fft))
            #
            # return the log(power()) of the transformed vector
            # v1
            # COMMENTED logspec = numpy.log(numpy.dot(power, self.filters).clip(self.CUTOFF, numpy.inf))
            # COMMENTED return numpy.dot(logspec, self.s2dct) / self.filter_bank_size
            # v2
            return numpy.log(numpy.dot(power, self.filters).clip(self.CUTOFF, numpy.inf))

        if len(data.shape) != 1:
            self.log_exc(u"The audio data must be a 1D numpy array (mono).", None, True, ValueError)
        if len(data) < 1:
            self.log_exc(u"The audio data must not be empty.", None, True, ValueError)

        self.data = data
        self.sample_rate = sample_rate

        # number of samples in the audio
        data_length = len(self.data)

        # frame length in number of samples
        frame_length = int(self.window_length * self.sample_rate)

        # frame length must be at least equal to the FFT order
        frame_length_padded = max(frame_length, self.fft_order)

        # frame shift in number of samples
        frame_shift = int(self.window_shift * self.sample_rate)

        # number of MFCC vectors (one for each frame)
        # this number includes the last shift,
        # where the data will be padded with zeros
        # if the remaining samples are less than frame_length_padded
        number_of_frames = int((1.0 * data_length) / frame_shift)

        # create Hamming window
        self.hamming_window = numpy.hamming(frame_length_padded)

        # build Mel filter bank
        self._create_mel_filter_bank()

        # pre-emphasize the entire audio data
        self._pre_emphasis()

        # allocate the MFCCs matrix
        # v1
        # COMMENTED mfcc = numpy.zeros((number_of_frames, self.mfcc_size), 'float64')
        # v2
        mfcc = numpy.zeros((number_of_frames, self.filter_bank_size), 'float64')

        # compute MFCCs one frame at a time
        for frame_index in range(number_of_frames):
            # COMMENTED print("Computing frame %d / %d" % (frame_index, number_of_frames))

            # get the start and end indices for this frame,
            # do not overrun the data length
            frame_start = frame_index * frame_shift
            frame_end = min(frame_start + frame_length_padded, data_length)

            # frame is zero-padded if the remaining samples
            # are less than its length
            frame = numpy.zeros(frame_length_padded)
            frame[0:(frame_end - frame_start)] = self.data[frame_start:frame_end]

            # process the frame
            mfcc[frame_index] = _process_frame(self, frame)

        # v1
        # COMMENTED return mfcc
        # v2
        # return the dot product with the DCT matrix
        return numpy.dot(mfcc, self.s2dct) / self.filter_bank_size


def mfccs_to_secs(params, val):
    return val * params.hop_length / params.sr

def secs_to_mfccs(params, val):
    return int(val * params.sr / params.hop_length)
    
class AlignmentPair:

    def __init__(self, params, q_audio, r_audio):

        self.params = params
        self.query_audio = q_audio
        self.ref_audio = r_audio
        
        assert len(q_audio.labels) == len(r_audio.labels)
                    
    def _calc_alignment_deviation(self, query_labels, 
                                 aligned_indices, 
                                 aligned_indices_mfcc):
    
        total_st_diff, total_end_diff = 0,0
        total_st_diff_mfcc, total_end_diff_mfcc = 0,0
        params = self.params
            
        assert len(query_labels) == len(aligned_indices)
        
        for i in range(0, len(query_labels)):
            exp_st = query_labels[i]["start"]
            exp_end = query_labels[i]["end"]
            act_st = aligned_indices[i]["start"]
            act_end = aligned_indices[i]["end"]
            
            exp_st_mfcc = secs_to_mfccs(params, query_labels[i]["start"])
            exp_end_mfcc = secs_to_mfccs(params, query_labels[i]["end"])
            act_st_mfcc = aligned_indices_mfcc[i]["start"]
            act_end_mfcc = aligned_indices_mfcc[i]["end"]
            
            total_st_diff += abs(exp_st - act_st)
            total_end_diff += abs(exp_end - act_end)
    
            total_st_diff_mfcc += abs(exp_st_mfcc - act_st_mfcc)
            total_end_diff_mfcc += abs(exp_end_mfcc - act_end_mfcc)
    
        return total_st_diff, total_end_diff, total_st_diff_mfcc, total_end_diff_mfcc
    
    def _find_alignment_range(self, start, end, wp, search_start):

        alignment_st, alignment_end = -1, -1
        for i in range(search_start, len(wp)):

            if (wp[i][1] == start and alignment_st == -1):
                assert alignment_end == -1
                alignment_st = wp[i][0]
                
            if (wp[i][1] > end):
                if (end != wp[i-1][1]):
                    print("end %d i %d val %d curr %d" 
                          %(end, i, wp[i-1][1], wp[i][1]))
                    assert 0
                alignment_end = wp[i-1][0]
                break

        if (alignment_st == -1):
            print("ERROR : i %d start %d len %d" 
                  %(i, search_start, len(wp)))
        if (alignment_end == -1):
            alignment_end = wp[i][0]
            
        return alignment_st, alignment_end, i-1

    def _get_alignment_indices(self, wp, ref_labels):
        aligned_indices = []
        aligned_indices_mfcc = []
        search_start = 0
        for i in range(0, len(ref_labels)):
            ref_st = secs_to_mfccs(self.params, ref_labels[i]["start"])
            ref_end = secs_to_mfccs(self.params, ref_labels[i]["end"])
            alignment_st, alignment_end, search_start = \
            self._find_alignment_range(ref_st, ref_end, wp, search_start)
            aligned_indices_mfcc.append(
                                {"start": alignment_st, 
                               "end": alignment_end})
            aligned_indices.append(
                            {"start": mfccs_to_secs(self.params, alignment_st), 
                             "end": mfccs_to_secs(self.params, alignment_end)})
        return aligned_indices, aligned_indices_mfcc

    def get_alignment_deviation_normal(self):
        wp = self.wp[::-1]
        aligned_indices, aligned_indices_mfcc = \
            self._get_alignment_indices(wp, self.ref_audio.labels)
        return self._calc_alignment_deviation(self.query_audio.labels, 
                                     aligned_indices, 
                                     aligned_indices_mfcc)

    def get_alignment_deviation_swap(self):
        wp = [(point[1], point[0]) for point in self.wp]
        wp = wp[::-1]
        aligned_indices, aligned_indices_mfcc = \
            self._get_alignment_indices(wp, self.query_audio.labels)
        return self._calc_alignment_deviation(self.ref_audio.labels, 
                                     aligned_indices, 
                                     aligned_indices_mfcc)
    
    def dump_warping_path(self, f_name):
        
        with open(f_name, "wb") as f:
            f.write(struct.pack("<i", len(self.wp)))
            for x, y in self.wp:
              f.write(struct.pack("<ii", x, y))
              
    def set_warping_path(self, f_name):
        self.wp= []
        with open(f_name, "rb") as f:
            # Read the number of elements
            num_elements = struct.unpack("<i", f.read(4))[0]
            print(num_elements)
        
            for _ in range(num_elements):
              x, y = struct.unpack("<ii", f.read(8))
              self.wp.append((x, y))    

class AlignmentPairLibrosa(AlignmentPair):

    def get_warping_path(self):

        params = self.params
        q_audio = self.query_audio
        r_audio = self.ref_audio
        
        g_c_val = True
        if (params.dtw_algorithm == AlignmentAlgorithm.DTW_EXACT):
            g_c_val = False
        
        assert len(q_audio.labels) == len(r_audio.labels)
                
        #distance = cdist(q_audio.mfcc.T, r_audio.mfcc.T)
        #D, self.wp = librosa.sequence.dtw(C = distance, subseq=False)
        _, self.wp = librosa.sequence.dtw(q_audio.mfcc, 
                                          r_audio.mfcc,
                                          global_constraints=g_c_val,
                                          backtrack=True)

class AlignmentPairAeneas(AlignmentPair):

    def get_warping_path(self):

        params = self.params
        q_audio = self.query_audio
        r_audio = self.ref_audio
        
        assert len(q_audio.labels) == len(r_audio.labels)
                
        a_dtw = aeneas_dtw(params, q_audio, r_audio)
        self.wp = a_dtw.compute_path()

class AudioText:
    
    def __init__(self, params, filename, labelname):
        self.params = params
        self.filename = filename
        self.labelname = labelname
        self.labels  = self._construct_labels(labelname)
        self.audio, sample_rate = librosa.load(self.filename, sr=params.sr)

    def _construct_labels(self, labelname):
        
        begin, end = -1,-1
        labels = []
        word="NULL"
        with open(labelname, "r", encoding="utf-8") as fp:
            lines = fp.readlines()
            line_idx = 0
            for line in lines:
                word = 'begin'
                if line.find(word) != -1:
                    parts = line.split(": \"")
                    assert(end == -1)
                    assert(begin == -1)            
                    begin = float(parts[1][0:-3])
                word = 'end'
                if line.find(word) != -1:
                    parts = line.split(": \"")
                    assert(end == -1)
                    assert(begin != -1)            
                    end = float(parts[1][0:-3])
                word = 'lines'
                if line.find(word) != -1:
                    word = lines[line_idx + 1]
                    labels.append({"start": begin, 
                                   "end": end, "text": word[5:-2]})
                    begin, end = -1,-1
                line_idx += 1
        return labels    
    
class AudioTextLibrosa(AudioText):
    def calc_mfcc(self, params):
        self.mfcc = librosa.feature.mfcc(
            y=self.audio,
            sr=params.sr,
            n_mfcc=params.n_mfcc,
            win_length=params.win_length,
            hop_length=params.hop_length,
            n_mels = params.n_mel,
            n_fft = params.n_fft,
            fmin = params.low_freq,
            fmax = params.high_freq,
            center=False,
        )
        self.__middle_begin = 0
        self.__middle_end = self.mfcc.shape[1]

class AudioTextAeneas(AudioText):
    def calc_mfcc(self, params):
        self.mfcc = aeneas_mfcc(params
            ).compute_from_data(
            self.audio, params.sr
        ).transpose()
                
class Alignment:

    def __init__(self,
               sr=SAMPLE_RATE, 
               n_fft=NUM_FFT,
               hop_length=HOP_LENGTH,
               window_length=WINDOW_LENGTH, 
               n_mfcc=NUM_MFCC, 
               n_mel=NUM_MELS, 
               low_freq=LOWER_FREQ, 
               high_freq=HIGHEST_FREQ,
               algorithm=DTW_ALGORITHM
               ):
        self.sr = sr
        self.n_fft = n_fft
        self.win_length = window_length
        self.hop_length = hop_length
        self.n_mfcc = n_mfcc
        self.n_mel = n_mel
        self.low_freq = low_freq
        self.high_freq = high_freq
        self.dtw_algorithm = algorithm
        
class AlignmentLibrosa(Alignment):

    def audio_text(self, filename, labelname):
        return AudioTextLibrosa(self, filename, labelname)
    
    def alignment_pair(self, q_audio, r_audio):
        return AlignmentPairLibrosa(self, q_audio, r_audio)
    
class AlignmentAeneas(Alignment):
    def __init__(self, 
                sr=SAMPLE_RATE, 
                n_fft=NUM_FFT,
                hop_length=HOP_LENGTH,
                window_length=WINDOW_LENGTH, 
                n_mfcc=NUM_MFCC, 
                n_mel=NUM_MELS, 
                low_freq=LOWER_FREQ, 
                high_freq=HIGHEST_FREQ,
                algorithm=DTW_ALGORITHM,
                fft_order=FFT_ORDER,
                emphasis_factor = EMPHASIS_FACTOR,
                dtw_margin=DTW_MARGIN):
        super().__init__(sr=SAMPLE_RATE, 
                       n_fft=n_fft,
                       hop_length=hop_length,
                       window_length=window_length, 
                       n_mfcc=n_mfcc, 
                       n_mel=n_mel, 
                       low_freq=low_freq, 
                       high_freq=high_freq,
                       algorithm=algorithm
                       )
        self.fft_order = fft_order
        self.emphasis_factor = emphasis_factor
        self.dtw_margin = dtw_margin
        
    def audio_text(self, filename, labelname):
        return AudioTextAeneas(self, filename, labelname)
    
    def alignment_pair(self, q_audio, r_audio):
        return AlignmentPairAeneas(self, q_audio, r_audio)

# %% [markdown]
# 1. Create an alignment object for librosa based alignment.
# 2. Parse the dataset directory and create an audio text object for each of the 14 datasets.
#    Load the audio, calulate the mfcc's and read the json file prepared using finetune aeneas
#    and get the start and end labels.

# %%
g_l = AlignmentLibrosa(algorithm=AlignmentAlgorithm.DTW_STRIPE)

# %%
import os
import glob
at_l_arr = []
dir = r"C:\Users\Lenovo\Desktop\sishya\audio alignment vs\audio_alignment - nama\dataset"
for sb in os.listdir(dir):
    f_a = r"%s\audio.mp3"%(os.path.join(dir, sb))       
    f_l = r"%s\label.json"%(os.path.join(dir, sb))

    at_l = g_l.audio_text(f_a, f_l)
    at_l.calc_mfcc(g_l)
    at_l_arr.append(at_l)

# %% [markdown]
# 1. For the 14 datasets, do an alignment with self.
# 2. Get the warping path and dump it as a binary file.
# 3. From the warping path, calculate the deviation.
#    That is - the start and end lables of the reference as well as the query are known.
#    See where the start and end of the references map to in the query. These will be the aligned indices.
#    The difference from the expected (obtained from finetuning query audio) is the alignment deviation.
# 4. Swap the query and reference. This is just a sanity check in this experiment. It's purpose will be clear
#    in the next experiment.

# %%
for r_idx in range(0, len(at_l_arr)):
    print("Doing for r:", r_idx)
    ap_l = g_l.alignment_pair(at_l_arr[r_idx], at_l_arr[r_idx])
    ap_l.get_warping_path()
    ap_l.dump_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\librosa_stripe\%d_%d.bin" %(r_idx, r_idx))
    print("normal deviation :")
    print(ap_l.get_alignment_deviation_normal())
    print("swap  deviation :")
    print(ap_l.get_alignment_deviation_swap())
# Out:
# Doing for r: 0
# normal deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# swap  deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# Doing for r: 1
# normal deviation :
# (1.3800000000003765, 1.5000000000002673, 0, 3)
# swap  deviation :
# (1.3800000000003765, 1.5000000000002673, 0, 3)
# Doing for r: 2
# normal deviation :
# (2.4599999999998694, 2.5799999999997603, 0, 3)
# swap  deviation :
# (2.4599999999998694, 2.5799999999997603, 0, 3)
# Doing for r: 3
# normal deviation :
# (1.6599999999997337, 1.7799999999997382, 0, 3)
# swap  deviation :
# (1.6599999999997337, 1.7799999999997382, 0, 3)
# Doing for r: 4
# normal deviation :
# (1.5199999999990403, 1.6399999999991586, 0, 3)
# swap  deviation :
# (1.5199999999990403, 1.6399999999991586, 0, 3)
# Doing for r: 5
# normal deviation :
# (1.839999999999077, 1.959999999998968, 0, 3)
# swap  deviation :
# (1.839999999999077, 1.959999999998968, 0, 3)
# Doing for r: 6
# normal deviation :
# (3.560000000000267, 3.680000000000158, 0, 3)
# swap  deviation :
# (3.560000000000267, 3.680000000000158, 0, 3)
# Doing for r: 7
# normal deviation :
# (2.2599999999996077, 2.379999999999726, 0, 3)
# swap  deviation :
# (2.2599999999996077, 2.379999999999726, 0, 3)
# Doing for r: 8
# normal deviation :
# (1.500000000000643, 1.6200000000006476, 0, 3)
# swap  deviation :
# (1.500000000000643, 1.6200000000006476, 0, 3)
# Doing for r: 9
# normal deviation :
# (0.9799999999998303, 1.0999999999998349, 0, 3)
# swap  deviation :
# (0.9799999999998303, 1.0999999999998349, 0, 3)
# Doing for r: 10
# normal deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# swap  deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# Doing for r: 11
# normal deviation :
# (1.6800000000000286, 1.8000000000001468, 0, 3)
# swap  deviation :
# (1.6800000000000286, 1.8000000000001468, 0, 3)
# Doing for r: 12
# normal deviation :
# (2.3000000000000327, 2.4200000000000372, 0, 3)
# swap  deviation :
# (2.3000000000000327, 2.4200000000000372, 0, 3)
# Doing for r: 13
# normal deviation :
# (1.240000000000176, 1.3600000000002943, 0, 3)
# swap  deviation :
# (1.240000000000176, 1.3600000000002943, 0, 3)

# %% [markdown]
# Read from the binary file and ensure that the deviation values match.

# %%
for r_idx in range(0, len(at_l_arr)):
    print("Checking form bin file for r:", r_idx)
    ap_l_b = g_l.alignment_pair(at_l_arr[r_idx], at_l_arr[r_idx])
    ap_l_b.set_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\librosa_stripe\%d_%d.bin" %(r_idx, r_idx))
    print("bin file normal deviation :")
    print(ap_l_b.get_alignment_deviation_normal())
    print("bin file swap  deviation :")
    print(ap_l_b.get_alignment_deviation_swap())
# Out:
# Checking form bin file for r: 0
# 30251
# bin file normal deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# bin file swap  deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# Checking form bin file for r: 1
# 28773
# bin file normal deviation :
# (1.3800000000003765, 1.5000000000002673, 0, 3)
# bin file swap  deviation :
# (1.3800000000003765, 1.5000000000002673, 0, 3)
# Checking form bin file for r: 2
# 31376
# bin file normal deviation :
# (2.4599999999998694, 2.5799999999997603, 0, 3)
# bin file swap  deviation :
# (2.4599999999998694, 2.5799999999997603, 0, 3)
# Checking form bin file for r: 3
# 25193
# bin file normal deviation :
# (1.6599999999997337, 1.7799999999997382, 0, 3)
# bin file swap  deviation :
# (1.6599999999997337, 1.7799999999997382, 0, 3)
# Checking form bin file for r: 4
# 38596
# bin file normal deviation :
# (1.5199999999990403, 1.6399999999991586, 0, 3)
# bin file swap  deviation :
# (1.5199999999990403, 1.6399999999991586, 0, 3)
# Checking form bin file for r: 5
# 30313
# bin file normal deviation :
# (1.839999999999077, 1.959999999998968, 0, 3)
# bin file swap  deviation :
# (1.839999999999077, 1.959999999998968, 0, 3)
# Checking form bin file for r: 6
# 35225
# bin file normal deviation :
# (3.560000000000267, 3.680000000000158, 0, 3)
# bin file swap  deviation :
# (3.560000000000267, 3.680000000000158, 0, 3)
# Checking form bin file for r: 7
# 26553
# bin file normal deviation :
# (2.2599999999996077, 2.379999999999726, 0, 3)
# bin file swap  deviation :
# (2.2599999999996077, 2.379999999999726, 0, 3)
# Checking form bin file for r: 8
# 25020
# bin file normal deviation :
# (1.500000000000643, 1.6200000000006476, 0, 3)
# bin file swap  deviation :
# (1.500000000000643, 1.6200000000006476, 0, 3)
# Checking form bin file for r: 9
# 23510
# bin file normal deviation :
# (0.9799999999998303, 1.0999999999998349, 0, 3)
# bin file swap  deviation :
# (0.9799999999998303, 1.0999999999998349, 0, 3)
# Checking form bin file for r: 10
# 25015
# bin file normal deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# bin file swap  deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# Checking form bin file for r: 11
# 28714
# bin file normal deviation :
# (1.6800000000000286, 1.8000000000001468, 0, 3)
# bin file swap  deviation :
# (1.6800000000000286, 1.8000000000001468, 0, 3)
# Checking form bin file for r: 12
# 24926
# bin file normal deviation :
# (2.3000000000000327, 2.4200000000000372, 0, 3)
# bin file swap  deviation :
# (2.3000000000000327, 2.4200000000000372, 0, 3)
# Checking form bin file for r: 13
# 29396
# bin file normal deviation :
# (1.240000000000176, 1.3600000000002943, 0, 3)
# bin file swap  deviation :
# (1.240000000000176, 1.3600000000002943, 0, 3)

# %% [markdown]
# RESULTS AND OBSERVATIONS:
#
# 1. The deviations were minimal.
# 2. In most cases the mfcc indices mathched correctly, but in some very few cases they did not.
#    This is the limitation of the algorithm.
# 3. Even in cases where mfcc indices matched, the timestamps did not match.
#    This is because of the error in conversion when timestamps get converted to mfcc indices and back to milliseconds.
#
# Time taken for the experiment:
# Each alignment finished in about a minute.

# %% [markdown]
# DOING THE SAME FOR AENEAS

# %% [markdown]
# Create an object for doing aeneas alignment. And do the alignment with self and
# dump the warp path and check the deviation values.

# %%
g_a = AlignmentAeneas(algorithm=AlignmentAlgorithm.DTW_STRIPE)

# %%
import os
import glob
at_a_arr = []
dir = r"C:\Users\Lenovo\Desktop\sishya\audio alignment vs\audio_alignment - nama\dataset"
for sb in os.listdir(dir):
    f_a = r"%s\audio.mp3"%(os.path.join(dir, sb))       
    f_l = r"%s\label.json"%(os.path.join(dir, sb))

    at_a = g_a.audio_text(f_a, f_l)
    at_a.calc_mfcc(g_a)
    at_a_arr.append(at_a)

# %%
for r_idx in range(0, len(at_a_arr)):
    print("Doing for r:", r_idx)
    ap_a = g_a.alignment_pair(at_a_arr[r_idx], at_a_arr[r_idx])
    ap_a.get_warping_path()
    ap_a.dump_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\aeneas_stripe\%d_%d.bin" %(r_idx, r_idx))
    print("normal deviation :")
    print(ap_a.get_alignment_deviation_normal())
    print("swap  deviation :")
    print(ap_a.get_alignment_deviation_swap())
# Out:
# Doing for r: 0
# normal deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# swap  deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# Doing for r: 1
# normal deviation :
# (2.6200000000001014, 2.660000000000065, 31, 32)
# swap  deviation :
# (31.820000000000885, 31.86000000000085, 761, 762)
# Doing for r: 2
# normal deviation :
# (2.4599999999998694, 2.499999999999833, 0, 1)
# swap  deviation :
# (2.4599999999998694, 2.499999999999833, 0, 1)
# Doing for r: 3
# normal deviation :
# (1.6599999999997337, 1.6999999999996973, 0, 1)
# swap  deviation :
# (1.6599999999997337, 1.6999999999996973, 0, 1)
# Doing for r: 4
# normal deviation :
# (1.5199999999990403, 1.559999999999004, 0, 1)
# swap  deviation :
# (1.5199999999990403, 1.559999999999004, 0, 1)
# Doing for r: 5
# normal deviation :
# (1.839999999999077, 1.8799999999990407, 0, 1)
# swap  deviation :
# (1.839999999999077, 1.8799999999990407, 0, 1)
# Doing for r: 6
# normal deviation :
# (3.560000000000267, 3.6000000000002306, 0, 1)
# swap  deviation :
# (3.560000000000267, 3.6000000000002306, 0, 1)
# Doing for r: 7
# normal deviation :
# (2.2599999999996077, 2.2999999999995713, 0, 1)
# swap  deviation :
# (2.2599999999996077, 2.2999999999995713, 0, 1)
# Doing for r: 8
# normal deviation :
# (1.500000000000643, 1.5400000000006067, 0, 1)
# swap  deviation :
# (1.500000000000643, 1.5400000000006067, 0, 1)
# Doing for r: 9
# normal deviation :
# (0.9799999999998303, 1.019999999999794, 0, 1)
# swap  deviation :
# (0.9799999999998303, 1.019999999999794, 0, 1)
# Doing for r: 10
# normal deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# swap  deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# Doing for r: 11
# normal deviation :
# (1.6800000000000286, 1.7200000000002196, 0, 1)
# swap  deviation :
# (1.6800000000000286, 1.7200000000002196, 0, 1)
# Doing for r: 12
# normal deviation :
# (2.3000000000000327, 2.3399999999999963, 0, 1)
# swap  deviation :
# (2.3000000000000327, 2.3399999999999963, 0, 1)
# Doing for r: 13
# normal deviation :
# (1.240000000000176, 1.2800000000001397, 0, 1)
# swap  deviation :
# (1.240000000000176, 1.2800000000001397, 0, 1)

# %%
for r_idx in range(0, len(at_a_arr)):
    print("Checking form bin file for r:", r_idx)
    ap_a_b = g_a.alignment_pair(at_a_arr[r_idx], at_a_arr[r_idx])
    ap_a_b.set_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\aeneas_stripe\%d_%d.bin" %(r_idx, r_idx))
    print("bin file normal deviation :")
    print(ap_a_b.get_alignment_deviation_normal())
    print("bin file swap  deviation :")
    print(ap_a_b.get_alignment_deviation_swap())
# Out:
# Checking form bin file for r: 0
# 30267
# bin file normal deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# bin file swap  deviation :
# (1.179999999999815, 1.1999999999997968, 0, 0)
# Checking form bin file for r: 1
# 31509
# bin file normal deviation :
# (2.6200000000001014, 2.660000000000065, 31, 32)
# bin file swap  deviation :
# (31.820000000000885, 31.86000000000085, 761, 762)
# Checking form bin file for r: 2
# 31378
# bin file normal deviation :
# (2.4599999999998694, 2.499999999999833, 0, 1)
# bin file swap  deviation :
# (2.4599999999998694, 2.499999999999833, 0, 1)
# Checking form bin file for r: 3
# 25195
# bin file normal deviation :
# (1.6599999999997337, 1.6999999999996973, 0, 1)
# bin file swap  deviation :
# (1.6599999999997337, 1.6999999999996973, 0, 1)
# Checking form bin file for r: 4
# 38598
# bin file normal deviation :
# (1.5199999999990403, 1.559999999999004, 0, 1)
# bin file swap  deviation :
# (1.5199999999990403, 1.559999999999004, 0, 1)
# Checking form bin file for r: 5
# 30315
# bin file normal deviation :
# (1.839999999999077, 1.8799999999990407, 0, 1)
# bin file swap  deviation :
# (1.839999999999077, 1.8799999999990407, 0, 1)
# Checking form bin file for r: 6
# 35227
# bin file normal deviation :
# (3.560000000000267, 3.6000000000002306, 0, 1)
# bin file swap  deviation :
# (3.560000000000267, 3.6000000000002306, 0, 1)
# Checking form bin file for r: 7
# 26555
# bin file normal deviation :
# (2.2599999999996077, 2.2999999999995713, 0, 1)
# bin file swap  deviation :
# (2.2599999999996077, 2.2999999999995713, 0, 1)
# Checking form bin file for r: 8
# 25022
# bin file normal deviation :
# (1.500000000000643, 1.5400000000006067, 0, 1)
# bin file swap  deviation :
# (1.500000000000643, 1.5400000000006067, 0, 1)
# Checking form bin file for r: 9
# 23512
# bin file normal deviation :
# (0.9799999999998303, 1.019999999999794, 0, 1)
# bin file swap  deviation :
# (0.9799999999998303, 1.019999999999794, 0, 1)
# Checking form bin file for r: 10
# 25017
# bin file normal deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# bin file swap  deviation :
# (1.3799999999997756, 1.3999999999998711, 0, 0)
# Checking form bin file for r: 11
# 28716
# bin file normal deviation :
# (1.6800000000000286, 1.7200000000002196, 0, 1)
# bin file swap  deviation :
# (1.6800000000000286, 1.7200000000002196, 0, 1)
# Checking form bin file for r: 12
# 24928
# bin file normal deviation :
# (2.3000000000000327, 2.3399999999999963, 0, 1)
# bin file swap  deviation :
# (2.3000000000000327, 2.3399999999999963, 0, 1)
# Checking form bin file for r: 13
# 29398
# bin file normal deviation :
# (1.240000000000176, 1.2800000000001397, 0, 1)
# bin file swap  deviation :
# (1.240000000000176, 1.2800000000001397, 0, 1)

# %% [markdown]
# RESULTS AND OBSERVATIONS:
# 1. The second dataset had a big deviation.
# 2. And the swapped warping path gave a mismatching deviation value.
# THIS HAS TO BE LOOKED AT.
#
# Time taken for the experiments:
# Each alignment took about 5-6 mins, much more than that for librosa.

# %% [markdown]
# NEXT EXPERIMENT - Seeing which reference has the minimum deviation.

# %% [markdown]
# 1. For each dataset, calculate the alignment against 13 other datasets.
# 2. This should be 14*13=182 alignment calculations.
# 3. But this can be halved, as the alignment ds0 vs ds1 is same as ds1 vs ds0, with the warping path points swapped.
# 4. So, calculate just 91 alignments and do a swap of the warping path to get the other alignment.
# 5. Then for each alignment calculate the deviations from the expected.
# 6. Print the total deviations for the 14 references.

# %% [markdown]
# FIRST LIBROSA

# %%
import numpy as np
dev_for_ref = np.zeros(len(at_l_arr), dtype=float)
cnt_for_ref = np.zeros(len(at_l_arr), dtype=int)

for r_idx in range(0, len(at_l_arr)):
    print("Doing for r:", r_idx)
    for q_idx in range(r_idx+1, len(at_l_arr)):
        print("Doing for q:", q_idx)
        ap_l = g_l.alignment_pair(at_l_arr[q_idx], at_l_arr[r_idx])
        ap_l.get_warping_path()
        ap_l.dump_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\librosa_stripe\%d_%d.bin" %(q_idx, r_idx))
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_l.get_alignment_deviation_normal()
        st_diff = st_diff / len(ap_l.query_audio.labels)
        end_diff = end_diff / len(ap_l.query_audio.labels)
        
        print("normal deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(q_idx, r_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[r_idx] += (st_diff+end_diff)/2
        cnt_for_ref[r_idx] += 1
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_l.get_alignment_deviation_swap()

        st_diff = st_diff / len(ap_l.ref_audio.labels)
        end_diff = end_diff / len(ap_l.ref_audio.labels)
        
        print("swap deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(r_idx, q_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[q_idx] += (st_diff+end_diff)/2
        cnt_for_ref[q_idx] += 1
# Out:
# Doing for r: 0
# Doing for q: 1
# normal deviation q 1 ref 0 : st 0.188254 end 0.190159 avg 0.189206 mfcc_st 2072 mfcc_end 2093
# swap deviation q 0 ref 1 : st 0.075057 end 0.082268 avg 0.078662 mfcc_st 832 mfcc_end 912
# Doing for q: 2
# normal deviation q 2 ref 0 : st 0.195782 end 0.219546 avg 0.207664 mfcc_st 2165 mfcc_end 2428
# swap deviation q 0 ref 2 : st 0.152880 end 0.185034 avg 0.168957 mfcc_st 1677 mfcc_end 2032
# Doing for q: 3
# normal deviation q 3 ref 0 : st 0.081950 end 0.082222 avg 0.082086 mfcc_st 904 mfcc_end 907
# swap deviation q 0 ref 3 : st 0.103537 end 0.110748 avg 0.107143 mfcc_st 1135 mfcc_end 1215
# Doing for q: 4
# normal deviation q 4 ref 0 : st 0.151927 end 0.152381 avg 0.152154 mfcc_st 1688 mfcc_end 1693
# swap deviation q 0 ref 4 : st 0.116417 end 0.123628 avg 0.120023 mfcc_st 1273 mfcc_end 1353
# Doing for q: 5
# normal deviation q 5 ref 0 : st 0.217868 end 0.218503 avg 0.218186 mfcc_st 2416 mfcc_end 2423
# swap deviation q 0 ref 5 : st 0.210023 end 0.217234 avg 0.213628 mfcc_st 2309 mfcc_end 2389
# Doing for q: 6
# normal deviation q 6 ref 0 : st 0.366349 end 0.366984 avg 0.366667 mfcc_st 4086 mfcc_end 4093
# swap deviation q 0 ref 6 : st 0.194512 end 0.201723 avg 0.198118 mfcc_st 2132 mfcc_end 2212
# Doing for q: 7
# normal deviation q 7 ref 0 : st 0.135918 end 0.150431 avg 0.143175 mfcc_st 1512 mfcc_end 1673
# swap deviation q 0 ref 7 : st 0.207302 end 0.226485 avg 0.216893 mfcc_st 2277 mfcc_end 2489
# Doing for q: 8
# normal deviation q 8 ref 0 : st 0.081315 end 0.081769 avg 0.081542 mfcc_st 896 mfcc_end 901
# swap deviation q 0 ref 8 : st 0.084399 end 0.091610 avg 0.088005 mfcc_st 929 mfcc_end 1009
# Doing for q: 9
# normal deviation q 9 ref 0 : st 0.081224 end 0.081859 avg 0.081542 mfcc_st 896 mfcc_end 903
# swap deviation q 0 ref 9 : st 0.111338 end 0.118549 avg 0.114943 mfcc_st 1228 mfcc_end 1308
# Doing for q: 10
# normal deviation q 10 ref 0 : st 0.066440 end 0.066848 avg 0.066644 mfcc_st 729 mfcc_end 733
# swap deviation q 0 ref 10 : st 0.073605 end 0.080816 avg 0.077211 mfcc_st 815 mfcc_end 895
# Doing for q: 11
# normal deviation q 11 ref 0 : st 0.077279 end 0.077642 avg 0.077460 mfcc_st 852 mfcc_end 856
# swap deviation q 0 ref 11 : st 0.076327 end 0.083537 avg 0.079932 mfcc_st 837 mfcc_end 917
# Doing for q: 12
# normal deviation q 12 ref 0 : st 0.088027 end 0.088753 avg 0.088390 mfcc_st 984 mfcc_end 992
# swap deviation q 0 ref 12 : st 0.093832 end 0.101043 avg 0.097438 mfcc_st 1028 mfcc_end 1108
# Doing for q: 13
# normal deviation q 13 ref 0 : st 0.120181 end 0.120998 avg 0.120590 mfcc_st 1327 mfcc_end 1336
# swap deviation q 0 ref 13 : st 0.107347 end 0.114558 avg 0.110952 mfcc_st 1177 mfcc_end 1257
# Doing for r: 1
# Doing for q: 2
# normal deviation q 2 ref 1 : st 0.151429 end 0.175102 avg 0.163265 mfcc_st 1679 mfcc_end 1941
# swap deviation q 1 ref 2 : st 0.238503 end 0.248209 avg 0.243356 mfcc_st 2616 mfcc_end 2723
# Doing for q: 3
# normal deviation q 3 ref 1 : st 0.079864 end 0.080136 avg 0.080000 mfcc_st 887 mfcc_end 890
# swap deviation q 1 ref 3 : st 0.210204 end 0.210476 avg 0.210340 mfcc_st 2313 mfcc_end 2316
# Doing for q: 4
# normal deviation q 4 ref 1 : st 0.236100 end 0.236372 avg 0.236236 mfcc_st 2600 mfcc_end 2603
# swap deviation q 1 ref 4 : st 0.242404 end 0.242676 avg 0.242540 mfcc_st 2658 mfcc_end 2661
# Doing for q: 5
# normal deviation q 5 ref 1 : st 0.229569 end 0.229841 avg 0.229705 mfcc_st 2543 mfcc_end 2546
# swap deviation q 1 ref 5 : st 0.270794 end 0.271066 avg 0.270930 mfcc_st 2981 mfcc_end 2984
# Doing for q: 6
# normal deviation q 6 ref 1 : st 0.285986 end 0.286259 avg 0.286122 mfcc_st 3191 mfcc_end 3194
# swap deviation q 1 ref 6 : st 0.242857 end 0.243129 avg 0.242993 mfcc_st 2663 mfcc_end 2666
# Doing for q: 7
# normal deviation q 7 ref 1 : st 0.139728 end 0.154150 avg 0.146939 mfcc_st 1557 mfcc_end 1717
# swap deviation q 1 ref 7 : st 0.230794 end 0.239864 avg 0.235329 mfcc_st 2533 mfcc_end 2633
# Doing for q: 8
# normal deviation q 8 ref 1 : st 0.097823 end 0.098095 avg 0.097959 mfcc_st 1076 mfcc_end 1079
# swap deviation q 1 ref 8 : st 0.181361 end 0.181633 avg 0.181497 mfcc_st 2002 mfcc_end 2005
# Doing for q: 9
# normal deviation q 9 ref 1 : st 0.086032 end 0.086304 avg 0.086168 mfcc_st 953 mfcc_end 956
# swap deviation q 1 ref 9 : st 0.230431 end 0.230703 avg 0.230567 mfcc_st 2539 mfcc_end 2542
# Doing for q: 10
# normal deviation q 10 ref 1 : st 0.083946 end 0.083991 avg 0.083968 mfcc_st 920 mfcc_end 920
# swap deviation q 1 ref 10 : st 0.213923 end 0.214195 avg 0.214059 mfcc_st 2363 mfcc_end 2366
# Doing for q: 11
# normal deviation q 11 ref 1 : st 0.105760 end 0.106032 avg 0.105896 mfcc_st 1168 mfcc_end 1171
# swap deviation q 1 ref 11 : st 0.223537 end 0.223810 avg 0.223673 mfcc_st 2460 mfcc_end 2463
# Doing for q: 12
# normal deviation q 12 ref 1 : st 0.088662 end 0.088934 avg 0.088798 mfcc_st 994 mfcc_end 997
# swap deviation q 1 ref 12 : st 0.190703 end 0.190975 avg 0.190839 mfcc_st 2102 mfcc_end 2105
# Doing for q: 13
# normal deviation q 13 ref 1 : st 0.156825 end 0.157098 avg 0.156961 mfcc_st 1734 mfcc_end 1737
# swap deviation q 1 ref 13 : st 0.185896 end 0.186168 avg 0.186032 mfcc_st 2037 mfcc_end 2040
# Doing for r: 2
# Doing for q: 3
# normal deviation q 3 ref 2 : st 0.099274 end 0.101088 avg 0.100181 mfcc_st 1091 mfcc_end 1111
# swap deviation q 2 ref 3 : st 0.126757 end 0.127211 avg 0.126984 mfcc_st 1397 mfcc_end 1403
# Doing for q: 4
# normal deviation q 4 ref 2 : st 0.297052 end 0.329615 avg 0.313333 mfcc_st 3280 mfcc_end 3639
# swap deviation q 2 ref 4 : st 0.277687 end 0.302902 avg 0.290295 mfcc_st 3067 mfcc_end 3345
# Doing for q: 5
# normal deviation q 5 ref 2 : st 0.262041 end 0.280454 avg 0.271247 mfcc_st 2893 mfcc_end 3096
# swap deviation q 2 ref 5 : st 0.282404 end 0.304263 avg 0.293333 mfcc_st 3105 mfcc_end 3347
# Doing for q: 6
# normal deviation q 6 ref 2 : st 0.365624 end 0.372336 avg 0.368980 mfcc_st 4060 mfcc_end 4134
# swap deviation q 2 ref 6 : st 0.166667 end 0.189977 avg 0.178322 mfcc_st 1812 mfcc_end 2070
# Doing for q: 7
# normal deviation q 7 ref 2 : st 0.109796 end 0.109252 avg 0.109524 mfcc_st 1211 mfcc_end 1204
# swap deviation q 2 ref 7 : st 0.176553 end 0.174921 avg 0.175737 mfcc_st 1934 mfcc_end 1917
# Doing for q: 8
# normal deviation q 8 ref 2 : st 0.122948 end 0.132744 avg 0.127846 mfcc_st 1350 mfcc_end 1458
# swap deviation q 2 ref 8 : st 0.144535 end 0.168390 avg 0.156463 mfcc_st 1598 mfcc_end 1862
# Doing for q: 9
# normal deviation q 9 ref 2 : st 0.103084 end 0.109524 avg 0.106304 mfcc_st 1130 mfcc_end 1201
# swap deviation q 2 ref 9 : st 0.151973 end 0.174558 avg 0.163265 mfcc_st 1679 mfcc_end 1929
# Doing for q: 10
# normal deviation q 10 ref 2 : st 0.116689 end 0.123628 avg 0.120159 mfcc_st 1289 mfcc_end 1365
# swap deviation q 2 ref 10 : st 0.139456 end 0.162948 avg 0.151202 mfcc_st 1546 mfcc_end 1806
# Doing for q: 11
# normal deviation q 11 ref 2 : st 0.116281 end 0.123628 avg 0.119955 mfcc_st 1271 mfcc_end 1352
# swap deviation q 2 ref 11 : st 0.126667 end 0.150522 avg 0.138594 mfcc_st 1397 mfcc_end 1661
# Doing for q: 12
# normal deviation q 12 ref 2 : st 0.145714 end 0.150703 avg 0.148209 mfcc_st 1608 mfcc_end 1662
# swap deviation q 2 ref 12 : st 0.157868 end 0.180635 avg 0.169252 mfcc_st 1745 mfcc_end 1997
# Doing for q: 13
# normal deviation q 13 ref 2 : st 0.156825 end 0.169796 avg 0.163311 mfcc_st 1724 mfcc_end 1867
# swap deviation q 2 ref 13 : st 0.158957 end 0.182630 avg 0.170794 mfcc_st 1758 mfcc_end 2020
# Doing for r: 3
# Doing for q: 4
# normal deviation q 4 ref 3 : st 0.205986 end 0.206259 avg 0.206122 mfcc_st 2265 mfcc_end 2268
# swap deviation q 3 ref 4 : st 0.123401 end 0.123673 avg 0.123537 mfcc_st 1356 mfcc_end 1359
# Doing for q: 5
# normal deviation q 5 ref 3 : st 0.213696 end 0.213968 avg 0.213832 mfcc_st 2365 mfcc_end 2368
# swap deviation q 3 ref 5 : st 0.150884 end 0.151156 avg 0.151020 mfcc_st 1658 mfcc_end 1661
# Doing for q: 6
# normal deviation q 6 ref 3 : st 0.383311 end 0.383583 avg 0.383447 mfcc_st 4236 mfcc_end 4239
# swap deviation q 3 ref 6 : st 0.110068 end 0.110340 avg 0.110204 mfcc_st 1205 mfcc_end 1208
# Doing for q: 7
# normal deviation q 7 ref 3 : st 0.095918 end 0.116599 avg 0.106259 mfcc_st 1063 mfcc_end 1291
# swap deviation q 3 ref 7 : st 0.094014 end 0.094921 avg 0.094467 mfcc_st 1027 mfcc_end 1037
# Doing for q: 8
# normal deviation q 8 ref 3 : st 0.107347 end 0.107619 avg 0.107483 mfcc_st 1178 mfcc_end 1181
# swap deviation q 3 ref 8 : st 0.086304 end 0.086576 avg 0.086440 mfcc_st 954 mfcc_end 957
# Doing for q: 9
# normal deviation q 9 ref 3 : st 0.094467 end 0.094739 avg 0.094603 mfcc_st 1039 mfcc_end 1042
# swap deviation q 3 ref 9 : st 0.092562 end 0.092834 avg 0.092698 mfcc_st 1028 mfcc_end 1031
# Doing for q: 10
# normal deviation q 10 ref 3 : st 0.112880 end 0.112925 avg 0.112902 mfcc_st 1240 mfcc_end 1240
# swap deviation q 3 ref 10 : st 0.091565 end 0.091837 avg 0.091701 mfcc_st 1016 mfcc_end 1019
# Doing for q: 11
# normal deviation q 11 ref 3 : st 0.104943 end 0.105215 avg 0.105079 mfcc_st 1146 mfcc_end 1149
# swap deviation q 3 ref 11 : st 0.087211 end 0.087483 avg 0.087347 mfcc_st 956 mfcc_end 959
# Doing for q: 12
# normal deviation q 12 ref 3 : st 0.104263 end 0.104535 avg 0.104399 mfcc_st 1156 mfcc_end 1159
# swap deviation q 3 ref 12 : st 0.088571 end 0.088844 avg 0.088707 mfcc_st 977 mfcc_end 980
# Doing for q: 13
# normal deviation q 13 ref 3 : st 0.138776 end 0.139048 avg 0.138912 mfcc_st 1535 mfcc_end 1538
# swap deviation q 3 ref 13 : st 0.091111 end 0.091383 avg 0.091247 mfcc_st 1001 mfcc_end 1004
# Doing for r: 4
# Doing for q: 5
# normal deviation q 5 ref 4 : st 0.257959 end 0.258231 avg 0.258095 mfcc_st 2850 mfcc_end 2853
# swap deviation q 4 ref 5 : st 0.306213 end 0.306485 avg 0.306349 mfcc_st 3372 mfcc_end 3375
# Doing for q: 6
# normal deviation q 6 ref 4 : st 0.398277 end 0.398549 avg 0.398413 mfcc_st 4413 mfcc_end 4416
# swap deviation q 4 ref 6 : st 0.203719 end 0.203991 avg 0.203855 mfcc_st 2238 mfcc_end 2241
# Doing for q: 7
# normal deviation q 7 ref 4 : st 0.173379 end 0.186893 avg 0.180136 mfcc_st 1923 mfcc_end 2073
# swap deviation q 4 ref 7 : st 0.265669 end 0.276825 avg 0.271247 mfcc_st 2918 mfcc_end 3041
# Doing for q: 8
# normal deviation q 8 ref 4 : st 0.188980 end 0.189252 avg 0.189116 mfcc_st 2080 mfcc_end 2083
# swap deviation q 4 ref 8 : st 0.300771 end 0.301043 avg 0.300907 mfcc_st 3327 mfcc_end 3330
# Doing for q: 9
# normal deviation q 9 ref 4 : st 0.117143 end 0.117415 avg 0.117279 mfcc_st 1282 mfcc_end 1285
# swap deviation q 4 ref 9 : st 0.164989 end 0.165261 avg 0.165125 mfcc_st 1826 mfcc_end 1829
# Doing for q: 10
# normal deviation q 10 ref 4 : st 74.011111 end 74.011156 avg 74.011134 mfcc_st 815993 mfcc_end 815993
# swap deviation q 4 ref 10 : st 118.377143 end 118.377415 avg 118.377279 mfcc_st 1305094 mfcc_end 1305097
# Doing for q: 11
# normal deviation q 11 ref 4 : st 0.126440 end 0.126712 avg 0.126576 mfcc_st 1388 mfcc_end 1391
# swap deviation q 4 ref 11 : st 0.160181 end 0.160454 avg 0.160317 mfcc_st 1772 mfcc_end 1775
# Doing for q: 12
# normal deviation q 12 ref 4 : st 0.424444 end 0.424717 avg 0.424580 mfcc_st 4677 mfcc_end 4680
# swap deviation q 4 ref 12 : st 0.681179 end 0.681451 avg 0.681315 mfcc_st 7512 mfcc_end 7515
# Doing for q: 13
# normal deviation q 13 ref 4 : st 0.165261 end 0.165533 avg 0.165397 mfcc_st 1831 mfcc_end 1834
# swap deviation q 4 ref 13 : st 0.175238 end 0.175510 avg 0.175374 mfcc_st 1939 mfcc_end 1942
# Doing for r: 5
# Doing for q: 6
# normal deviation q 6 ref 5 : st 0.390658 end 0.390930 avg 0.390794 mfcc_st 4316 mfcc_end 4319
# swap deviation q 5 ref 6 : st 0.260136 end 0.260408 avg 0.260272 mfcc_st 2864 mfcc_end 2867
# Doing for q: 7
# normal deviation q 7 ref 5 : st 0.163220 end 0.163673 avg 0.163447 mfcc_st 1793 mfcc_end 1799
# swap deviation q 5 ref 7 : st 0.243084 end 0.240363 avg 0.241723 mfcc_st 2684 mfcc_end 2654
# Doing for q: 8
# normal deviation q 8 ref 5 : st 0.203583 end 0.203855 avg 0.203719 mfcc_st 2237 mfcc_end 2240
# swap deviation q 5 ref 8 : st 0.232834 end 0.233107 avg 0.232971 mfcc_st 2579 mfcc_end 2582
# Doing for q: 9
# normal deviation q 9 ref 5 : st 0.157959 end 0.158231 avg 0.158095 mfcc_st 1731 mfcc_end 1734
# swap deviation q 5 ref 9 : st 0.226757 end 0.227029 avg 0.226893 mfcc_st 2515 mfcc_end 2518
# Doing for q: 10
# normal deviation q 10 ref 5 : st 0.210295 end 0.210340 avg 0.210317 mfcc_st 2311 mfcc_end 2311
# swap deviation q 5 ref 10 : st 0.234104 end 0.234376 avg 0.234240 mfcc_st 2602 mfcc_end 2605
# Doing for q: 11
# normal deviation q 11 ref 5 : st 0.180862 end 0.181134 avg 0.180998 mfcc_st 1986 mfcc_end 1989
# swap deviation q 5 ref 11 : st 0.201361 end 0.201633 avg 0.201497 mfcc_st 2233 mfcc_end 2236
# Doing for q: 12
# normal deviation q 12 ref 5 : st 0.270068 end 0.270340 avg 0.270204 mfcc_st 2970 mfcc_end 2973
# swap deviation q 5 ref 12 : st 0.292336 end 0.292608 avg 0.292472 mfcc_st 3238 mfcc_end 3241
# Doing for q: 13
# normal deviation q 13 ref 5 : st 0.241451 end 0.241723 avg 0.241587 mfcc_st 2660 mfcc_end 2663
# swap deviation q 5 ref 13 : st 0.221134 end 0.221406 avg 0.221270 mfcc_st 2451 mfcc_end 2454
# Doing for r: 6
# Doing for q: 7
# normal deviation q 7 ref 6 : st 0.125215 end 0.139637 avg 0.132426 mfcc_st 1371 mfcc_end 1531
# swap deviation q 6 ref 7 : st 0.383855 end 0.389660 avg 0.386757 mfcc_st 4217 mfcc_end 4281
# Doing for q: 8
# normal deviation q 8 ref 6 : st 0.183175 end 0.183447 avg 0.183311 mfcc_st 2006 mfcc_end 2009
# swap deviation q 6 ref 8 : st 0.353107 end 0.353379 avg 0.353243 mfcc_st 3934 mfcc_end 3937
# Doing for q: 9
# normal deviation q 9 ref 6 : st 0.119138 end 0.119410 avg 0.119274 mfcc_st 1303 mfcc_end 1306
# swap deviation q 6 ref 9 : st 0.364082 end 0.364354 avg 0.364218 mfcc_st 4048 mfcc_end 4051
# Doing for q: 10
# normal deviation q 10 ref 6 : st 0.194875 end 0.194921 avg 0.194898 mfcc_st 2139 mfcc_end 2139
# swap deviation q 6 ref 10 : st 0.361088 end 0.361361 avg 0.361224 mfcc_st 4023 mfcc_end 4026
# Doing for q: 11
# normal deviation q 11 ref 6 : st 0.134603 end 0.134875 avg 0.134739 mfcc_st 1468 mfcc_end 1471
# swap deviation q 6 ref 11 : st 0.360544 end 0.360816 avg 0.360680 mfcc_st 4019 mfcc_end 4022
# Doing for q: 12
# normal deviation q 12 ref 6 : st 0.194059 end 0.194331 avg 0.194195 mfcc_st 2129 mfcc_end 2132
# swap deviation q 6 ref 12 : st 0.331791 end 0.332063 avg 0.331927 mfcc_st 3675 mfcc_end 3678
# Doing for q: 13
# normal deviation q 13 ref 6 : st 0.223946 end 0.224218 avg 0.224082 mfcc_st 2461 mfcc_end 2464
# swap deviation q 6 ref 13 : st 0.323447 end 0.323719 avg 0.323583 mfcc_st 3592 mfcc_end 3595
# Doing for r: 7
# Doing for q: 8
# normal deviation q 8 ref 7 : st 0.130023 end 0.127211 avg 0.128617 mfcc_st 1431 mfcc_end 1400
# swap deviation q 7 ref 8 : st 0.138095 end 0.119138 avg 0.128617 mfcc_st 1533 mfcc_end 1325
# Doing for q: 9
# normal deviation q 9 ref 7 : st 0.122132 end 0.125941 avg 0.124036 mfcc_st 1336 mfcc_end 1378
# swap deviation q 7 ref 9 : st 0.130476 end 0.141088 avg 0.135782 mfcc_st 1453 mfcc_end 1571
# Doing for q: 10
# normal deviation q 10 ref 7 : st 0.134830 end 0.136054 avg 0.135442 mfcc_st 1477 mfcc_end 1490
# swap deviation q 7 ref 10 : st 0.139365 end 0.141088 avg 0.140227 mfcc_st 1552 mfcc_end 1572
# Doing for q: 11
# normal deviation q 11 ref 7 : st 0.190113 end 0.204717 avg 0.197415 mfcc_st 2081 mfcc_end 2242
# swap deviation q 7 ref 11 : st 0.164127 end 0.184807 avg 0.174467 mfcc_st 1822 mfcc_end 2050
# Doing for q: 12
# normal deviation q 12 ref 7 : st 0.131293 end 0.149433 avg 0.140363 mfcc_st 1447 mfcc_end 1647
# swap deviation q 7 ref 12 : st 0.166213 end 0.186893 avg 0.176553 mfcc_st 1838 mfcc_end 2066
# Doing for q: 13
# normal deviation q 13 ref 7 : st 0.295692 end 0.293243 avg 0.294467 mfcc_st 3259 mfcc_end 3232
# swap deviation q 7 ref 13 : st 0.133832 end 0.113968 avg 0.123900 mfcc_st 1480 mfcc_end 1262
# Doing for r: 8
# Doing for q: 9
# normal deviation q 9 ref 8 : st 0.086395 end 0.086667 avg 0.086531 mfcc_st 955 mfcc_end 958
# swap deviation q 8 ref 9 : st 0.117324 end 0.117596 avg 0.117460 mfcc_st 1293 mfcc_end 1296
# Doing for q: 10
# normal deviation q 10 ref 8 : st 0.088571 end 0.088617 avg 0.088594 mfcc_st 968 mfcc_end 968
# swap deviation q 8 ref 10 : st 0.091111 end 0.091383 avg 0.091247 mfcc_st 1006 mfcc_end 1009
# Doing for q: 11
# normal deviation q 11 ref 8 : st 0.107302 end 0.107574 avg 0.107438 mfcc_st 1189 mfcc_end 1192
# swap deviation q 8 ref 11 : st 0.098549 end 0.098821 avg 0.098685 mfcc_st 1089 mfcc_end 1092
# Doing for q: 12
# normal deviation q 12 ref 8 : st 0.097642 end 0.097914 avg 0.097778 mfcc_st 1083 mfcc_end 1086
# swap deviation q 8 ref 12 : st 0.100907 end 0.101179 avg 0.101043 mfcc_st 1113 mfcc_end 1116
# Doing for q: 13
# normal deviation q 13 ref 8 : st 0.126168 end 0.126440 avg 0.126304 mfcc_st 1397 mfcc_end 1400
# swap deviation q 8 ref 13 : st 0.112154 end 0.112426 avg 0.112290 mfcc_st 1238 mfcc_end 1241
# Doing for r: 9
# Doing for q: 10
# normal deviation q 10 ref 9 : st 0.110612 end 0.110658 avg 0.110635 mfcc_st 1218 mfcc_end 1218
# swap deviation q 9 ref 10 : st 0.085397 end 0.085669 avg 0.085533 mfcc_st 944 mfcc_end 947
# Doing for q: 11
# normal deviation q 11 ref 9 : st 0.113107 end 0.113379 avg 0.113243 mfcc_st 1247 mfcc_end 1250
# swap deviation q 9 ref 11 : st 0.093379 end 0.093651 avg 0.093515 mfcc_st 1023 mfcc_end 1026
# Doing for q: 12
# normal deviation q 12 ref 9 : st 0.119864 end 0.120136 avg 0.120000 mfcc_st 1320 mfcc_end 1323
# swap deviation q 9 ref 12 : st 0.094830 end 0.095102 avg 0.094966 mfcc_st 1047 mfcc_end 1050
# Doing for q: 13
# normal deviation q 13 ref 9 : st 0.133424 end 0.133696 avg 0.133560 mfcc_st 1477 mfcc_end 1480
# swap deviation q 9 ref 13 : st 0.095918 end 0.096190 avg 0.096054 mfcc_st 1052 mfcc_end 1055
# Doing for r: 10
# Doing for q: 11
# normal deviation q 11 ref 10 : st 0.105215 end 0.105488 avg 0.105351 mfcc_st 1165 mfcc_end 1168
# swap deviation q 10 ref 11 : st 0.091837 end 0.091882 avg 0.091859 mfcc_st 1007 mfcc_end 1007
# Doing for q: 12
# normal deviation q 12 ref 10 : st 0.094921 end 0.095193 avg 0.095057 mfcc_st 1059 mfcc_end 1062
# swap deviation q 10 ref 12 : st 0.097551 end 0.097596 avg 0.097574 mfcc_st 1064 mfcc_end 1064
# Doing for q: 13
# normal deviation q 13 ref 10 : st 0.144671 end 0.144943 avg 0.144807 mfcc_st 1600 mfcc_end 1603
# swap deviation q 10 ref 13 : st 0.124218 end 0.124263 avg 0.124240 mfcc_st 1366 mfcc_end 1366
# Doing for r: 11
# Doing for q: 12
# normal deviation q 12 ref 11 : st 0.117596 end 0.117868 avg 0.117732 mfcc_st 1300 mfcc_end 1303
# swap deviation q 11 ref 12 : st 0.125442 end 0.125714 avg 0.125578 mfcc_st 1382 mfcc_end 1385
# Doing for q: 13
# normal deviation q 13 ref 11 : st 0.143401 end 0.143673 avg 0.143537 mfcc_st 1580 mfcc_end 1583
# swap deviation q 11 ref 13 : st 0.105941 end 0.106213 avg 0.106077 mfcc_st 1168 mfcc_end 1171
# Doing for r: 12
# Doing for q: 13
# normal deviation q 13 ref 12 : st 0.230930 end 0.231202 avg 0.231066 mfcc_st 2549 mfcc_end 2552
# swap deviation q 12 ref 13 : st 0.200408 end 0.200680 avg 0.200544 mfcc_st 2210 mfcc_end 2213
# Doing for r: 13

# %%
dev_for_ref/len(at_l_arr)
# Out:
# array([0.13395044, 0.13147716, 0.16866861, 0.14410755, 5.4747943 ,
#        0.21817298, 0.16976352, 0.1887496 , 0.14534176, 0.14917072,
#        8.58350988, 0.14084548, 0.19133787, 0.14588273])

# %% [markdown]
# Checking if the warping path has been dumped correctly.
# Reading from the bin file and seeing that the deviation values asre the same.

# %%
import numpy as np
dev_for_ref = np.zeros(len(at_l_arr), dtype=float)
cnt_for_ref = np.zeros(len(at_l_arr), dtype=int)

for r_idx in range(0, len(at_l_arr)):
    print("Checking form bin file for r:", r_idx)
    for q_idx in range(r_idx+1, len(at_l_arr)):
        print("Checking for q:", q_idx)
        ap_l_b = g_l.alignment_pair(at_l_arr[q_idx], at_l_arr[r_idx])
        ap_l_b.set_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\librosa_stripe\%d_%d.bin" %(q_idx, r_idx))
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_l_b.get_alignment_deviation_normal()
        st_diff = st_diff / len(ap_l_b.query_audio.labels)
        end_diff = end_diff / len(ap_l_b.query_audio.labels)
        
        print("normal deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(q_idx, r_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[r_idx] += (st_diff+end_diff)/2
        cnt_for_ref[r_idx] += 1
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_l_b.get_alignment_deviation_swap()

        st_diff = st_diff / len(ap_l_b.ref_audio.labels)
        end_diff = end_diff / len(ap_l_b.ref_audio.labels)
        
        print("swap deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(r_idx, q_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[q_idx] += (st_diff+end_diff)/2
        cnt_for_ref[q_idx] += 1
# Out:
# Checking form bin file for r: 0
# Checking for q: 1
# 33543
# normal deviation q 1 ref 0 : st 0.188254 end 0.190159 avg 0.189206 mfcc_st 2072 mfcc_end 2093
# swap deviation q 0 ref 1 : st 0.075057 end 0.082268 avg 0.078662 mfcc_st 832 mfcc_end 912
# Checking for q: 2
# 33333
# normal deviation q 2 ref 0 : st 0.195782 end 0.219546 avg 0.207664 mfcc_st 2165 mfcc_end 2428
# swap deviation q 0 ref 2 : st 0.152880 end 0.185034 avg 0.168957 mfcc_st 1677 mfcc_end 2032
# Checking for q: 3
# 30921
# normal deviation q 3 ref 0 : st 0.081950 end 0.082222 avg 0.082086 mfcc_st 904 mfcc_end 907
# swap deviation q 0 ref 3 : st 0.103537 end 0.110748 avg 0.107143 mfcc_st 1135 mfcc_end 1215
# Checking for q: 4
# 39300
# normal deviation q 4 ref 0 : st 0.151927 end 0.152381 avg 0.152154 mfcc_st 1688 mfcc_end 1693
# swap deviation q 0 ref 4 : st 0.116417 end 0.123628 avg 0.120023 mfcc_st 1273 mfcc_end 1353
# Checking for q: 5
# 32229
# normal deviation q 5 ref 0 : st 0.217868 end 0.218503 avg 0.218186 mfcc_st 2416 mfcc_end 2423
# swap deviation q 0 ref 5 : st 0.210023 end 0.217234 avg 0.213628 mfcc_st 2309 mfcc_end 2389
# Checking for q: 6
# 36758
# normal deviation q 6 ref 0 : st 0.366349 end 0.366984 avg 0.366667 mfcc_st 4086 mfcc_end 4093
# swap deviation q 0 ref 6 : st 0.194512 end 0.201723 avg 0.198118 mfcc_st 2132 mfcc_end 2212
# Checking for q: 7
# 30687
# normal deviation q 7 ref 0 : st 0.135918 end 0.150431 avg 0.143175 mfcc_st 1512 mfcc_end 1673
# swap deviation q 0 ref 7 : st 0.207302 end 0.226485 avg 0.216893 mfcc_st 2277 mfcc_end 2489
# Checking for q: 8
# 30464
# normal deviation q 8 ref 0 : st 0.081315 end 0.081769 avg 0.081542 mfcc_st 896 mfcc_end 901
# swap deviation q 0 ref 8 : st 0.084399 end 0.091610 avg 0.088005 mfcc_st 929 mfcc_end 1009
# Checking for q: 9
# 30662
# normal deviation q 9 ref 0 : st 0.081224 end 0.081859 avg 0.081542 mfcc_st 896 mfcc_end 903
# swap deviation q 0 ref 9 : st 0.111338 end 0.118549 avg 0.114943 mfcc_st 1228 mfcc_end 1308
# Checking for q: 10
# 30531
# normal deviation q 10 ref 0 : st 0.066440 end 0.066848 avg 0.066644 mfcc_st 729 mfcc_end 733
# swap deviation q 0 ref 10 : st 0.073605 end 0.080816 avg 0.077211 mfcc_st 815 mfcc_end 895
# Checking for q: 11
# 31514
# normal deviation q 11 ref 0 : st 0.077279 end 0.077642 avg 0.077460 mfcc_st 852 mfcc_end 856
# swap deviation q 0 ref 11 : st 0.076327 end 0.083537 avg 0.079932 mfcc_st 837 mfcc_end 917
# Checking for q: 12
# 30510
# normal deviation q 12 ref 0 : st 0.088027 end 0.088753 avg 0.088390 mfcc_st 984 mfcc_end 992
# swap deviation q 0 ref 12 : st 0.093832 end 0.101043 avg 0.097438 mfcc_st 1028 mfcc_end 1108
# Checking for q: 13
# 32560
# normal deviation q 13 ref 0 : st 0.120181 end 0.120998 avg 0.120590 mfcc_st 1327 mfcc_end 1336
# swap deviation q 0 ref 13 : st 0.107347 end 0.114558 avg 0.110952 mfcc_st 1177 mfcc_end 1257
# Checking form bin file for r: 1
# Checking for q: 2
# 34577
# normal deviation q 2 ref 1 : st 0.151429 end 0.175102 avg 0.163265 mfcc_st 1679 mfcc_end 1941
# swap deviation q 1 ref 2 : st 0.238503 end 0.248209 avg 0.243356 mfcc_st 2616 mfcc_end 2723
# Checking for q: 3
# 30061
# normal deviation q 3 ref 1 : st 0.079864 end 0.080136 avg 0.080000 mfcc_st 887 mfcc_end 890
# swap deviation q 1 ref 3 : st 0.210204 end 0.210476 avg 0.210340 mfcc_st 2313 mfcc_end 2316
# Checking for q: 4
# 41100
# normal deviation q 4 ref 1 : st 0.236100 end 0.236372 avg 0.236236 mfcc_st 2600 mfcc_end 2603
# swap deviation q 1 ref 4 : st 0.242404 end 0.242676 avg 0.242540 mfcc_st 2658 mfcc_end 2661
# Checking for q: 5
# 32091
# normal deviation q 5 ref 1 : st 0.229569 end 0.229841 avg 0.229705 mfcc_st 2543 mfcc_end 2546
# swap deviation q 1 ref 5 : st 0.270794 end 0.271066 avg 0.270930 mfcc_st 2981 mfcc_end 2984
# Checking for q: 6
# 35735
# normal deviation q 6 ref 1 : st 0.285986 end 0.286259 avg 0.286122 mfcc_st 3191 mfcc_end 3194
# swap deviation q 1 ref 6 : st 0.242857 end 0.243129 avg 0.242993 mfcc_st 2663 mfcc_end 2666
# Checking for q: 7
# 30669
# normal deviation q 7 ref 1 : st 0.139728 end 0.154150 avg 0.146939 mfcc_st 1557 mfcc_end 1717
# swap deviation q 1 ref 7 : st 0.230794 end 0.239864 avg 0.235329 mfcc_st 2533 mfcc_end 2633
# Checking for q: 8
# 29281
# normal deviation q 8 ref 1 : st 0.097823 end 0.098095 avg 0.097959 mfcc_st 1076 mfcc_end 1079
# swap deviation q 1 ref 8 : st 0.181361 end 0.181633 avg 0.181497 mfcc_st 2002 mfcc_end 2005
# Checking for q: 9
# 29513
# normal deviation q 9 ref 1 : st 0.086032 end 0.086304 avg 0.086168 mfcc_st 953 mfcc_end 956
# swap deviation q 1 ref 9 : st 0.230431 end 0.230703 avg 0.230567 mfcc_st 2539 mfcc_end 2542
# Checking for q: 10
# 29217
# normal deviation q 10 ref 1 : st 0.083946 end 0.083991 avg 0.083968 mfcc_st 920 mfcc_end 920
# swap deviation q 1 ref 10 : st 0.213923 end 0.214195 avg 0.214059 mfcc_st 2363 mfcc_end 2366
# Checking for q: 11
# 31776
# normal deviation q 11 ref 1 : st 0.105760 end 0.106032 avg 0.105896 mfcc_st 1168 mfcc_end 1171
# swap deviation q 1 ref 11 : st 0.223537 end 0.223810 avg 0.223673 mfcc_st 2460 mfcc_end 2463
# Checking for q: 12
# 29572
# normal deviation q 12 ref 1 : st 0.088662 end 0.088934 avg 0.088798 mfcc_st 994 mfcc_end 997
# swap deviation q 1 ref 12 : st 0.190703 end 0.190975 avg 0.190839 mfcc_st 2102 mfcc_end 2105
# Checking for q: 13
# 31290
# normal deviation q 13 ref 1 : st 0.156825 end 0.157098 avg 0.156961 mfcc_st 1734 mfcc_end 1737
# swap deviation q 1 ref 13 : st 0.185896 end 0.186168 avg 0.186032 mfcc_st 2037 mfcc_end 2040
# Checking form bin file for r: 2
# Checking for q: 3
# 31504
# normal deviation q 3 ref 2 : st 0.099274 end 0.101088 avg 0.100181 mfcc_st 1091 mfcc_end 1111
# swap deviation q 2 ref 3 : st 0.126757 end 0.127211 avg 0.126984 mfcc_st 1397 mfcc_end 1403
# Checking for q: 4
# 39727
# normal deviation q 4 ref 2 : st 0.297052 end 0.329615 avg 0.313333 mfcc_st 3280 mfcc_end 3639
# swap deviation q 2 ref 4 : st 0.277687 end 0.302902 avg 0.290295 mfcc_st 3067 mfcc_end 3345
# Checking for q: 5
# 32913
# normal deviation q 5 ref 2 : st 0.262041 end 0.280454 avg 0.271247 mfcc_st 2893 mfcc_end 3096
# swap deviation q 2 ref 5 : st 0.282404 end 0.304263 avg 0.293333 mfcc_st 3105 mfcc_end 3347
# Checking for q: 6
# 37640
# normal deviation q 6 ref 2 : st 0.365624 end 0.372336 avg 0.368980 mfcc_st 4060 mfcc_end 4134
# swap deviation q 2 ref 6 : st 0.166667 end 0.189977 avg 0.178322 mfcc_st 1812 mfcc_end 2070
# Checking for q: 7
# 31496
# normal deviation q 7 ref 2 : st 0.109796 end 0.109252 avg 0.109524 mfcc_st 1211 mfcc_end 1204
# swap deviation q 2 ref 7 : st 0.176553 end 0.174921 avg 0.175737 mfcc_st 1934 mfcc_end 1917
# Checking for q: 8
# 32166
# normal deviation q 8 ref 2 : st 0.122948 end 0.132744 avg 0.127846 mfcc_st 1350 mfcc_end 1458
# swap deviation q 2 ref 8 : st 0.144535 end 0.168390 avg 0.156463 mfcc_st 1598 mfcc_end 1862
# Checking for q: 9
# 31688
# normal deviation q 9 ref 2 : st 0.103084 end 0.109524 avg 0.106304 mfcc_st 1130 mfcc_end 1201
# swap deviation q 2 ref 9 : st 0.151973 end 0.174558 avg 0.163265 mfcc_st 1679 mfcc_end 1929
# Checking for q: 10
# 31836
# normal deviation q 10 ref 2 : st 0.116689 end 0.123628 avg 0.120159 mfcc_st 1289 mfcc_end 1365
# swap deviation q 2 ref 10 : st 0.139456 end 0.162948 avg 0.151202 mfcc_st 1546 mfcc_end 1806
# Checking for q: 11
# 32170
# normal deviation q 11 ref 2 : st 0.116281 end 0.123628 avg 0.119955 mfcc_st 1271 mfcc_end 1352
# swap deviation q 2 ref 11 : st 0.126667 end 0.150522 avg 0.138594 mfcc_st 1397 mfcc_end 1661
# Checking for q: 12
# 32949
# normal deviation q 12 ref 2 : st 0.145714 end 0.150703 avg 0.148209 mfcc_st 1608 mfcc_end 1662
# swap deviation q 2 ref 12 : st 0.157868 end 0.180635 avg 0.169252 mfcc_st 1745 mfcc_end 1997
# Checking for q: 13
# 33459
# normal deviation q 13 ref 2 : st 0.156825 end 0.169796 avg 0.163311 mfcc_st 1724 mfcc_end 1867
# swap deviation q 2 ref 13 : st 0.158957 end 0.182630 avg 0.170794 mfcc_st 1758 mfcc_end 2020
# Checking form bin file for r: 3
# Checking for q: 4
# 38643
# normal deviation q 4 ref 3 : st 0.205986 end 0.206259 avg 0.206122 mfcc_st 2265 mfcc_end 2268
# swap deviation q 3 ref 4 : st 0.123401 end 0.123673 avg 0.123537 mfcc_st 1356 mfcc_end 1359
# Checking for q: 5
# 30551
# normal deviation q 5 ref 3 : st 0.213696 end 0.213968 avg 0.213832 mfcc_st 2365 mfcc_end 2368
# swap deviation q 3 ref 5 : st 0.150884 end 0.151156 avg 0.151020 mfcc_st 1658 mfcc_end 1661
# Checking for q: 6
# 35682
# normal deviation q 6 ref 3 : st 0.383311 end 0.383583 avg 0.383447 mfcc_st 4236 mfcc_end 4239
# swap deviation q 3 ref 6 : st 0.110068 end 0.110340 avg 0.110204 mfcc_st 1205 mfcc_end 1208
# Checking for q: 7
# 27069
# normal deviation q 7 ref 3 : st 0.095918 end 0.116599 avg 0.106259 mfcc_st 1063 mfcc_end 1291
# swap deviation q 3 ref 7 : st 0.094014 end 0.094921 avg 0.094467 mfcc_st 1027 mfcc_end 1037
# Checking for q: 8
# 26986
# normal deviation q 8 ref 3 : st 0.107347 end 0.107619 avg 0.107483 mfcc_st 1178 mfcc_end 1181
# swap deviation q 3 ref 8 : st 0.086304 end 0.086576 avg 0.086440 mfcc_st 954 mfcc_end 957
# Checking for q: 9
# 25970
# normal deviation q 9 ref 3 : st 0.094467 end 0.094739 avg 0.094603 mfcc_st 1039 mfcc_end 1042
# swap deviation q 3 ref 9 : st 0.092562 end 0.092834 avg 0.092698 mfcc_st 1028 mfcc_end 1031
# Checking for q: 10
# 26684
# normal deviation q 10 ref 3 : st 0.112880 end 0.112925 avg 0.112902 mfcc_st 1240 mfcc_end 1240
# swap deviation q 3 ref 10 : st 0.091565 end 0.091837 avg 0.091701 mfcc_st 1016 mfcc_end 1019
# Checking for q: 11
# 29073
# normal deviation q 11 ref 3 : st 0.104943 end 0.105215 avg 0.105079 mfcc_st 1146 mfcc_end 1149
# swap deviation q 3 ref 11 : st 0.087211 end 0.087483 avg 0.087347 mfcc_st 956 mfcc_end 959
# Checking for q: 12
# 27230
# normal deviation q 12 ref 3 : st 0.104263 end 0.104535 avg 0.104399 mfcc_st 1156 mfcc_end 1159
# swap deviation q 3 ref 12 : st 0.088571 end 0.088844 avg 0.088707 mfcc_st 977 mfcc_end 980
# Checking for q: 13
# 30244
# normal deviation q 13 ref 3 : st 0.138776 end 0.139048 avg 0.138912 mfcc_st 1535 mfcc_end 1538
# swap deviation q 3 ref 13 : st 0.091111 end 0.091383 avg 0.091247 mfcc_st 1001 mfcc_end 1004
# Checking form bin file for r: 4
# Checking for q: 5
# 39744
# normal deviation q 5 ref 4 : st 0.257959 end 0.258231 avg 0.258095 mfcc_st 2850 mfcc_end 2853
# swap deviation q 4 ref 5 : st 0.306213 end 0.306485 avg 0.306349 mfcc_st 3372 mfcc_end 3375
# Checking for q: 6
# 44560
# normal deviation q 6 ref 4 : st 0.398277 end 0.398549 avg 0.398413 mfcc_st 4413 mfcc_end 4416
# swap deviation q 4 ref 6 : st 0.203719 end 0.203991 avg 0.203855 mfcc_st 2238 mfcc_end 2241
# Checking for q: 7
# 38979
# normal deviation q 7 ref 4 : st 0.173379 end 0.186893 avg 0.180136 mfcc_st 1923 mfcc_end 2073
# swap deviation q 4 ref 7 : st 0.265669 end 0.276825 avg 0.271247 mfcc_st 2918 mfcc_end 3041
# Checking for q: 8
# 38696
# normal deviation q 8 ref 4 : st 0.188980 end 0.189252 avg 0.189116 mfcc_st 2080 mfcc_end 2083
# swap deviation q 4 ref 8 : st 0.300771 end 0.301043 avg 0.300907 mfcc_st 3327 mfcc_end 3330
# Checking for q: 9
# 38903
# normal deviation q 9 ref 4 : st 0.117143 end 0.117415 avg 0.117279 mfcc_st 1282 mfcc_end 1285
# swap deviation q 4 ref 9 : st 0.164989 end 0.165261 avg 0.165125 mfcc_st 1826 mfcc_end 1829
# Checking for q: 10
# 39114
# normal deviation q 10 ref 4 : st 74.011111 end 74.011156 avg 74.011134 mfcc_st 815993 mfcc_end 815993
# swap deviation q 4 ref 10 : st 118.377143 end 118.377415 avg 118.377279 mfcc_st 1305094 mfcc_end 1305097
# Checking for q: 11
# 39014
# normal deviation q 11 ref 4 : st 0.126440 end 0.126712 avg 0.126576 mfcc_st 1388 mfcc_end 1391
# swap deviation q 4 ref 11 : st 0.160181 end 0.160454 avg 0.160317 mfcc_st 1772 mfcc_end 1775
# Checking for q: 12
# 38629
# normal deviation q 12 ref 4 : st 0.424444 end 0.424717 avg 0.424580 mfcc_st 4677 mfcc_end 4680
# swap deviation q 4 ref 12 : st 0.681179 end 0.681451 avg 0.681315 mfcc_st 7512 mfcc_end 7515
# Checking for q: 13
# 41148
# normal deviation q 13 ref 4 : st 0.165261 end 0.165533 avg 0.165397 mfcc_st 1831 mfcc_end 1834
# swap deviation q 4 ref 13 : st 0.175238 end 0.175510 avg 0.175374 mfcc_st 1939 mfcc_end 1942
# Checking form bin file for r: 5
# Checking for q: 6
# 36204
# normal deviation q 6 ref 5 : st 0.390658 end 0.390930 avg 0.390794 mfcc_st 4316 mfcc_end 4319
# swap deviation q 5 ref 6 : st 0.260136 end 0.260408 avg 0.260272 mfcc_st 2864 mfcc_end 2867
# Checking for q: 7
# 30943
# normal deviation q 7 ref 5 : st 0.163220 end 0.163673 avg 0.163447 mfcc_st 1793 mfcc_end 1799
# swap deviation q 5 ref 7 : st 0.243084 end 0.240363 avg 0.241723 mfcc_st 2684 mfcc_end 2654
# Checking for q: 8
# 30715
# normal deviation q 8 ref 5 : st 0.203583 end 0.203855 avg 0.203719 mfcc_st 2237 mfcc_end 2240
# swap deviation q 5 ref 8 : st 0.232834 end 0.233107 avg 0.232971 mfcc_st 2579 mfcc_end 2582
# Checking for q: 9
# 30761
# normal deviation q 9 ref 5 : st 0.157959 end 0.158231 avg 0.158095 mfcc_st 1731 mfcc_end 1734
# swap deviation q 5 ref 9 : st 0.226757 end 0.227029 avg 0.226893 mfcc_st 2515 mfcc_end 2518
# Checking for q: 10
# 30606
# normal deviation q 10 ref 5 : st 0.210295 end 0.210340 avg 0.210317 mfcc_st 2311 mfcc_end 2311
# swap deviation q 5 ref 10 : st 0.234104 end 0.234376 avg 0.234240 mfcc_st 2602 mfcc_end 2605
# Checking for q: 11
# 31657
# normal deviation q 11 ref 5 : st 0.180862 end 0.181134 avg 0.180998 mfcc_st 1986 mfcc_end 1989
# swap deviation q 5 ref 11 : st 0.201361 end 0.201633 avg 0.201497 mfcc_st 2233 mfcc_end 2236
# Checking for q: 12
# 30927
# normal deviation q 12 ref 5 : st 0.270068 end 0.270340 avg 0.270204 mfcc_st 2970 mfcc_end 2973
# swap deviation q 5 ref 12 : st 0.292336 end 0.292608 avg 0.292472 mfcc_st 3238 mfcc_end 3241
# Checking for q: 13
# 32037
# normal deviation q 13 ref 5 : st 0.241451 end 0.241723 avg 0.241587 mfcc_st 2660 mfcc_end 2663
# swap deviation q 5 ref 13 : st 0.221134 end 0.221406 avg 0.221270 mfcc_st 2451 mfcc_end 2454
# Checking form bin file for r: 6
# Checking for q: 7
# 36036
# normal deviation q 7 ref 6 : st 0.125215 end 0.139637 avg 0.132426 mfcc_st 1371 mfcc_end 1531
# swap deviation q 6 ref 7 : st 0.383855 end 0.389660 avg 0.386757 mfcc_st 4217 mfcc_end 4281
# Checking for q: 8
# 35318
# normal deviation q 8 ref 6 : st 0.183175 end 0.183447 avg 0.183311 mfcc_st 2006 mfcc_end 2009
# swap deviation q 6 ref 8 : st 0.353107 end 0.353379 avg 0.353243 mfcc_st 3934 mfcc_end 3937
# Checking for q: 9
# 35391
# normal deviation q 9 ref 6 : st 0.119138 end 0.119410 avg 0.119274 mfcc_st 1303 mfcc_end 1306
# swap deviation q 6 ref 9 : st 0.364082 end 0.364354 avg 0.364218 mfcc_st 4048 mfcc_end 4051
# Checking for q: 10
# 35278
# normal deviation q 10 ref 6 : st 0.194875 end 0.194921 avg 0.194898 mfcc_st 2139 mfcc_end 2139
# swap deviation q 6 ref 10 : st 0.361088 end 0.361361 avg 0.361224 mfcc_st 4023 mfcc_end 4026
# Checking for q: 11
# 35942
# normal deviation q 11 ref 6 : st 0.134603 end 0.134875 avg 0.134739 mfcc_st 1468 mfcc_end 1471
# swap deviation q 6 ref 11 : st 0.360544 end 0.360816 avg 0.360680 mfcc_st 4019 mfcc_end 4022
# Checking for q: 12
# 35280
# normal deviation q 12 ref 6 : st 0.194059 end 0.194331 avg 0.194195 mfcc_st 2129 mfcc_end 2132
# swap deviation q 6 ref 12 : st 0.331791 end 0.332063 avg 0.331927 mfcc_st 3675 mfcc_end 3678
# Checking for q: 13
# 35611
# normal deviation q 13 ref 6 : st 0.223946 end 0.224218 avg 0.224082 mfcc_st 2461 mfcc_end 2464
# swap deviation q 6 ref 13 : st 0.323447 end 0.323719 avg 0.323583 mfcc_st 3592 mfcc_end 3595
# Checking form bin file for r: 7
# Checking for q: 8
# 26895
# normal deviation q 8 ref 7 : st 0.130023 end 0.127211 avg 0.128617 mfcc_st 1431 mfcc_end 1400
# swap deviation q 7 ref 8 : st 0.138095 end 0.119138 avg 0.128617 mfcc_st 1533 mfcc_end 1325
# Checking for q: 9
# 27001
# normal deviation q 9 ref 7 : st 0.122132 end 0.125941 avg 0.124036 mfcc_st 1336 mfcc_end 1378
# swap deviation q 7 ref 9 : st 0.130476 end 0.141088 avg 0.135782 mfcc_st 1453 mfcc_end 1571
# Checking for q: 10
# 26776
# normal deviation q 10 ref 7 : st 0.134830 end 0.136054 avg 0.135442 mfcc_st 1477 mfcc_end 1490
# swap deviation q 7 ref 10 : st 0.139365 end 0.141088 avg 0.140227 mfcc_st 1552 mfcc_end 1572
# Checking for q: 11
# 29301
# normal deviation q 11 ref 7 : st 0.190113 end 0.204717 avg 0.197415 mfcc_st 2081 mfcc_end 2242
# swap deviation q 7 ref 11 : st 0.164127 end 0.184807 avg 0.174467 mfcc_st 1822 mfcc_end 2050
# Checking for q: 12
# 26636
# normal deviation q 12 ref 7 : st 0.131293 end 0.149433 avg 0.140363 mfcc_st 1447 mfcc_end 1647
# swap deviation q 7 ref 12 : st 0.166213 end 0.186893 avg 0.176553 mfcc_st 1838 mfcc_end 2066
# Checking for q: 13
# 30835
# normal deviation q 13 ref 7 : st 0.295692 end 0.293243 avg 0.294467 mfcc_st 3259 mfcc_end 3232
# swap deviation q 7 ref 13 : st 0.133832 end 0.113968 avg 0.123900 mfcc_st 1480 mfcc_end 1262
# Checking form bin file for r: 8
# Checking for q: 9
# 25716
# normal deviation q 9 ref 8 : st 0.086395 end 0.086667 avg 0.086531 mfcc_st 955 mfcc_end 958
# swap deviation q 8 ref 9 : st 0.117324 end 0.117596 avg 0.117460 mfcc_st 1293 mfcc_end 1296
# Checking for q: 10
# 25688
# normal deviation q 10 ref 8 : st 0.088571 end 0.088617 avg 0.088594 mfcc_st 968 mfcc_end 968
# swap deviation q 8 ref 10 : st 0.091111 end 0.091383 avg 0.091247 mfcc_st 1006 mfcc_end 1009
# Checking for q: 11
# 28880
# normal deviation q 11 ref 8 : st 0.107302 end 0.107574 avg 0.107438 mfcc_st 1189 mfcc_end 1192
# swap deviation q 8 ref 11 : st 0.098549 end 0.098821 avg 0.098685 mfcc_st 1089 mfcc_end 1092
# Checking for q: 12
# 26414
# normal deviation q 12 ref 8 : st 0.097642 end 0.097914 avg 0.097778 mfcc_st 1083 mfcc_end 1086
# swap deviation q 8 ref 12 : st 0.100907 end 0.101179 avg 0.101043 mfcc_st 1113 mfcc_end 1116
# Checking for q: 13
# 29738
# normal deviation q 13 ref 8 : st 0.126168 end 0.126440 avg 0.126304 mfcc_st 1397 mfcc_end 1400
# swap deviation q 8 ref 13 : st 0.112154 end 0.112426 avg 0.112290 mfcc_st 1238 mfcc_end 1241
# Checking form bin file for r: 9
# Checking for q: 10
# 25642
# normal deviation q 10 ref 9 : st 0.110612 end 0.110658 avg 0.110635 mfcc_st 1218 mfcc_end 1218
# swap deviation q 9 ref 10 : st 0.085397 end 0.085669 avg 0.085533 mfcc_st 944 mfcc_end 947
# Checking for q: 11
# 28996
# normal deviation q 11 ref 9 : st 0.113107 end 0.113379 avg 0.113243 mfcc_st 1247 mfcc_end 1250
# swap deviation q 9 ref 11 : st 0.093379 end 0.093651 avg 0.093515 mfcc_st 1023 mfcc_end 1026
# Checking for q: 12
# 25728
# normal deviation q 12 ref 9 : st 0.119864 end 0.120136 avg 0.120000 mfcc_st 1320 mfcc_end 1323
# swap deviation q 9 ref 12 : st 0.094830 end 0.095102 avg 0.094966 mfcc_st 1047 mfcc_end 1050
# Checking for q: 13
# 30026
# normal deviation q 13 ref 9 : st 0.133424 end 0.133696 avg 0.133560 mfcc_st 1477 mfcc_end 1480
# swap deviation q 9 ref 13 : st 0.095918 end 0.096190 avg 0.096054 mfcc_st 1052 mfcc_end 1055
# Checking form bin file for r: 10
# Checking for q: 11
# 28825
# normal deviation q 11 ref 10 : st 0.105215 end 0.105488 avg 0.105351 mfcc_st 1165 mfcc_end 1168
# swap deviation q 10 ref 11 : st 0.091837 end 0.091882 avg 0.091859 mfcc_st 1007 mfcc_end 1007
# Checking for q: 12
# 26289
# normal deviation q 12 ref 10 : st 0.094921 end 0.095193 avg 0.095057 mfcc_st 1059 mfcc_end 1062
# swap deviation q 10 ref 12 : st 0.097551 end 0.097596 avg 0.097574 mfcc_st 1064 mfcc_end 1064
# Checking for q: 13
# 29630
# normal deviation q 13 ref 10 : st 0.144671 end 0.144943 avg 0.144807 mfcc_st 1600 mfcc_end 1603
# swap deviation q 10 ref 13 : st 0.124218 end 0.124263 avg 0.124240 mfcc_st 1366 mfcc_end 1366
# Checking form bin file for r: 11
# Checking for q: 12
# 28839
# normal deviation q 12 ref 11 : st 0.117596 end 0.117868 avg 0.117732 mfcc_st 1300 mfcc_end 1303
# swap deviation q 11 ref 12 : st 0.125442 end 0.125714 avg 0.125578 mfcc_st 1382 mfcc_end 1385
# Checking for q: 13
# 31991
# normal deviation q 13 ref 11 : st 0.143401 end 0.143673 avg 0.143537 mfcc_st 1580 mfcc_end 1583
# swap deviation q 11 ref 13 : st 0.105941 end 0.106213 avg 0.106077 mfcc_st 1168 mfcc_end 1171
# Checking form bin file for r: 12
# Checking for q: 13
# 29857
# normal deviation q 13 ref 12 : st 0.230930 end 0.231202 avg 0.231066 mfcc_st 2549 mfcc_end 2552
# swap deviation q 12 ref 13 : st 0.200408 end 0.200680 avg 0.200544 mfcc_st 2210 mfcc_end 2213
# Checking form bin file for r: 13

# %%
dev_for_ref/len(at_l_arr)
# Out:
# array([0.13395044, 0.13147716, 0.16866861, 0.14410755, 5.4747943 ,
#        0.21817298, 0.16976352, 0.1887496 , 0.14534176, 0.14917072,
#        8.58350988, 0.14084548, 0.19133787, 0.14588273])

# %% [markdown]
# NEXT, DOING THE SAME FOR AENEAS. FIRST CALCULATING THE WARP PATHS (AND SWAPS) AND DEVIATIONS

# %%
dev_for_ref = np.zeros(len(at_a_arr), dtype=float)
cnt_for_ref = np.zeros(len(at_a_arr), dtype=int)

for r_idx in range(0, len(at_a_arr)):
    print("Doing for r:", r_idx)
    for q_idx in range(r_idx+1, len(at_a_arr)):
        print("Doing for q:", q_idx)
        ap_a = g_a.alignment_pair(at_a_arr[q_idx], at_a_arr[r_idx])
        ap_a.get_warping_path()
        ap_a.dump_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\aeneas_stripe\%d_%d.bin" %(q_idx, r_idx))
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_a.get_alignment_deviation_normal()
        st_diff = st_diff / len(ap_a.query_audio.labels)
        end_diff = end_diff / len(ap_a.query_audio.labels)
        
        print("normal deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(q_idx, r_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[r_idx] += (st_diff+end_diff)/2
        cnt_for_ref[r_idx] += 1
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_a.get_alignment_deviation_swap()

        st_diff = st_diff / len(ap_a.ref_audio.labels)
        end_diff = end_diff / len(ap_a.ref_audio.labels)
        
        print("swap deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(r_idx, q_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[q_idx] += (st_diff+end_diff)/2
        cnt_for_ref[q_idx] += 1
# Out:
# Doing for r: 0
# Doing for q: 1
# normal deviation q 1 ref 0 : st 0.198685 end 0.200227 avg 0.199456 mfcc_st 2188 mfcc_end 2205
# swap deviation q 0 ref 1 : st 0.111519 end 0.118912 avg 0.115215 mfcc_st 1233 mfcc_end 1315
# Doing for q: 2
# normal deviation q 2 ref 0 : st 0.204399 end 0.227891 avg 0.216145 mfcc_st 2261 mfcc_end 2521
# swap deviation q 0 ref 2 : st 0.155601 end 0.187574 avg 0.171587 mfcc_st 1709 mfcc_end 2062
# Doing for q: 3
# normal deviation q 3 ref 0 : st 0.137007 end 0.137279 avg 0.137143 mfcc_st 1507 mfcc_end 1510
# swap deviation q 0 ref 3 : st 0.184082 end 0.191474 avg 0.187778 mfcc_st 2025 mfcc_end 2107
# Doing for q: 4
# normal deviation q 4 ref 0 : st 0.208798 end 0.212698 avg 0.210748 mfcc_st 2303 mfcc_end 2346
# swap deviation q 0 ref 4 : st 0.144717 end 0.152109 avg 0.148413 mfcc_st 1588 mfcc_end 1670
# Doing for q: 5
# normal deviation q 5 ref 0 : st 0.223220 end 0.228753 avg 0.225986 mfcc_st 2474 mfcc_end 2535
# swap deviation q 0 ref 5 : st 0.179456 end 0.186848 avg 0.183152 mfcc_st 1969 mfcc_end 2051
# Doing for q: 6
# normal deviation q 6 ref 0 : st 0.549297 end 0.553107 avg 0.551202 mfcc_st 6051 mfcc_end 6093
# swap deviation q 0 ref 6 : st 0.382993 end 0.390385 avg 0.386689 mfcc_st 4216 mfcc_end 4298
# Doing for q: 7
# normal deviation q 7 ref 0 : st 0.162494 end 0.174830 avg 0.168662 mfcc_st 1801 mfcc_end 1938
# swap deviation q 0 ref 7 : st 0.169025 end 0.180680 avg 0.174853 mfcc_st 1857 mfcc_end 1986
# Doing for q: 8
# normal deviation q 8 ref 0 : st 0.089660 end 0.090113 avg 0.089887 mfcc_st 990 mfcc_end 995
# swap deviation q 0 ref 8 : st 0.089841 end 0.097234 avg 0.093537 mfcc_st 992 mfcc_end 1074
# Doing for q: 9
# normal deviation q 9 ref 0 : st 0.103991 end 0.106531 avg 0.105261 mfcc_st 1149 mfcc_end 1177
# swap deviation q 0 ref 9 : st 0.162313 end 0.169705 avg 0.166009 mfcc_st 1787 mfcc_end 1869
# Doing for q: 10
# normal deviation q 10 ref 0 : st 0.070794 end 0.072653 avg 0.071723 mfcc_st 779 mfcc_end 799
# swap deviation q 0 ref 10 : st 0.083220 end 0.090431 avg 0.086825 mfcc_st 917 mfcc_end 997
# Doing for q: 11
# normal deviation q 11 ref 0 : st 0.120998 end 0.124444 avg 0.122721 mfcc_st 1332 mfcc_end 1370
# swap deviation q 0 ref 11 : st 0.125215 end 0.132608 avg 0.128912 mfcc_st 1377 mfcc_end 1459
# Doing for q: 12
# normal deviation q 12 ref 0 : st 0.174195 end 0.174830 avg 0.174512 mfcc_st 1929 mfcc_end 1936
# swap deviation q 0 ref 12 : st 0.201315 end 0.208707 avg 0.205011 mfcc_st 2216 mfcc_end 2298
# Doing for q: 13
# normal deviation q 13 ref 0 : st 0.135420 end 0.135692 avg 0.135556 mfcc_st 1500 mfcc_end 1503
# swap deviation q 0 ref 13 : st 0.085850 end 0.093243 avg 0.089546 mfcc_st 939 mfcc_end 1021
# Doing for r: 1
# Doing for q: 2
# normal deviation q 2 ref 1 : st 0.367029 end 0.390703 avg 0.378866 mfcc_st 4057 mfcc_end 4319
# swap deviation q 1 ref 2 : st 0.384444 end 0.406757 avg 0.395601 mfcc_st 4238 mfcc_end 4484
# Doing for q: 3
# normal deviation q 3 ref 1 : st 0.249841 end 0.249932 avg 0.249887 mfcc_st 2764 mfcc_end 2765
# swap deviation q 1 ref 3 : st 0.389070 end 0.389161 avg 0.389116 mfcc_st 4285 mfcc_end 4286
# Doing for q: 4
# normal deviation q 4 ref 1 : st 0.565442 end 0.565533 avg 0.565488 mfcc_st 6235 mfcc_end 6236
# swap deviation q 1 ref 4 : st 0.431973 end 0.432063 avg 0.432018 mfcc_st 4759 mfcc_end 4760
# Doing for q: 5
# normal deviation q 5 ref 1 : st 0.348934 end 0.349025 avg 0.348980 mfcc_st 3865 mfcc_end 3866
# swap deviation q 1 ref 5 : st 0.359501 end 0.359592 avg 0.359546 mfcc_st 3957 mfcc_end 3958
# Doing for q: 6
# normal deviation q 6 ref 1 : st 0.566349 end 0.566440 avg 0.566395 mfcc_st 6252 mfcc_end 6253
# swap deviation q 1 ref 6 : st 0.427982 end 0.428073 avg 0.428027 mfcc_st 4712 mfcc_end 4713
# Doing for q: 7
# normal deviation q 7 ref 1 : st 0.416916 end 0.437415 avg 0.427166 mfcc_st 4608 mfcc_end 4834
# swap deviation q 1 ref 7 : st 0.466531 end 0.488934 avg 0.477732 mfcc_st 5133 mfcc_end 5380
# Doing for q: 8
# normal deviation q 8 ref 1 : st 0.151156 end 0.151247 avg 0.151202 mfcc_st 1664 mfcc_end 1665
# swap deviation q 1 ref 8 : st 0.207211 end 0.207302 avg 0.207256 mfcc_st 2287 mfcc_end 2288
# Doing for q: 9
# normal deviation q 9 ref 1 : st 0.142449 end 0.142540 avg 0.142494 mfcc_st 1577 mfcc_end 1578
# swap deviation q 1 ref 9 : st 0.266077 end 0.266168 avg 0.266122 mfcc_st 2928 mfcc_end 2929
# Doing for q: 10
# normal deviation q 10 ref 1 : st 0.146893 end 0.147029 avg 0.146961 mfcc_st 1622 mfcc_end 1624
# swap deviation q 1 ref 10 : st 0.246667 end 0.246939 avg 0.246803 mfcc_st 2721 mfcc_end 2724
# Doing for q: 11
# normal deviation q 11 ref 1 : st 0.134694 end 0.134785 avg 0.134739 mfcc_st 1486 mfcc_end 1487
# swap deviation q 1 ref 11 : st 0.208209 end 0.208299 avg 0.208254 mfcc_st 2296 mfcc_end 2297
# Doing for q: 12
# normal deviation q 12 ref 1 : st 0.378549 end 0.378639 avg 0.378594 mfcc_st 4185 mfcc_end 4186
# swap deviation q 1 ref 12 : st 0.467528 end 0.467619 avg 0.467574 mfcc_st 5152 mfcc_end 5153
# Doing for q: 13
# normal deviation q 13 ref 1 : st 0.167075 end 0.167166 avg 0.167120 mfcc_st 1850 mfcc_end 1851
# swap deviation q 1 ref 13 : st 0.183810 end 0.183900 avg 0.183855 mfcc_st 2013 mfcc_end 2014
# Doing for r: 2
# Doing for q: 3
# normal deviation q 3 ref 2 : st 0.111882 end 0.114150 avg 0.113016 mfcc_st 1230 mfcc_end 1255
# swap deviation q 2 ref 3 : st 0.123946 end 0.147438 avg 0.135692 mfcc_st 1374 mfcc_end 1634
# Doing for q: 4
# normal deviation q 4 ref 2 : st 0.567075 end 0.571973 avg 0.569524 mfcc_st 6258 mfcc_end 6312
# swap deviation q 2 ref 4 : st 0.427166 end 0.452200 avg 0.439683 mfcc_st 4710 mfcc_end 4986
# Doing for q: 5
# normal deviation q 5 ref 2 : st 0.230385 end 0.229025 avg 0.229705 mfcc_st 2549 mfcc_end 2534
# swap deviation q 2 ref 5 : st 0.218549 end 0.221723 avg 0.220136 mfcc_st 2399 mfcc_end 2435
# Doing for q: 6
# normal deviation q 6 ref 2 : st 0.475193 end 0.472018 avg 0.473605 mfcc_st 5227 mfcc_end 5192
# swap deviation q 2 ref 6 : st 0.302721 end 0.284853 avg 0.293787 mfcc_st 3333 mfcc_end 3137
# Doing for q: 7
# normal deviation q 7 ref 2 : st 0.130748 end 0.130204 avg 0.130476 mfcc_st 1443 mfcc_end 1436
# swap deviation q 2 ref 7 : st 0.127120 end 0.126667 avg 0.126893 mfcc_st 1396 mfcc_end 1392
# Doing for q: 8
# normal deviation q 8 ref 2 : st 0.108707 end 0.111519 avg 0.110113 mfcc_st 1193 mfcc_end 1224
# swap deviation q 2 ref 8 : st 0.112880 end 0.137914 avg 0.125397 mfcc_st 1244 mfcc_end 1520
# Doing for q: 9
# normal deviation q 9 ref 2 : st 0.146349 end 0.153243 avg 0.149796 mfcc_st 1613 mfcc_end 1689
# swap deviation q 2 ref 9 : st 0.264989 end 0.288118 avg 0.276553 mfcc_st 2918 mfcc_end 3174
# Doing for q: 10
# normal deviation q 10 ref 2 : st 0.110159 end 0.115828 avg 0.112993 mfcc_st 1214 mfcc_end 1277
# swap deviation q 2 ref 10 : st 0.147347 end 0.170658 avg 0.159002 mfcc_st 1634 mfcc_end 1892
# Doing for q: 11
# normal deviation q 11 ref 2 : st 0.166893 end 0.174150 avg 0.170522 mfcc_st 1832 mfcc_end 1912
# swap deviation q 2 ref 11 : st 0.162585 end 0.186440 avg 0.174512 mfcc_st 1796 mfcc_end 2060
# Doing for q: 12
# normal deviation q 12 ref 2 : st 0.110794 end 0.112426 avg 0.111610 mfcc_st 1228 mfcc_end 1245
# swap deviation q 2 ref 12 : st 0.155238 end 0.165488 avg 0.160363 mfcc_st 1708 mfcc_end 1822
# Doing for q: 13
# normal deviation q 13 ref 2 : st 0.178594 end 0.177959 avg 0.178277 mfcc_st 1968 mfcc_end 1961
# swap deviation q 2 ref 13 : st 0.180181 end 0.162132 avg 0.171156 mfcc_st 1994 mfcc_end 1796
# Doing for r: 3
# Doing for q: 4
# normal deviation q 4 ref 3 : st 32.530703 end 32.530794 avg 32.530748 mfcc_st 358666 mfcc_end 358667
# swap deviation q 3 ref 4 : st 20.761043 end 20.761134 avg 20.761088 mfcc_st 228872 mfcc_end 228873
# Doing for q: 5
# normal deviation q 5 ref 3 : st 0.237551 end 0.237642 avg 0.237596 mfcc_st 2631 mfcc_end 2632
# swap deviation q 3 ref 5 : st 0.166757 end 0.166848 avg 0.166803 mfcc_st 1826 mfcc_end 1827
# Doing for q: 6
# normal deviation q 6 ref 3 : st 0.557279 end 0.557370 avg 0.557324 mfcc_st 6130 mfcc_end 6131
# swap deviation q 3 ref 6 : st 0.231882 end 0.231973 avg 0.231927 mfcc_st 2552 mfcc_end 2553
# Doing for q: 7
# normal deviation q 7 ref 3 : st 0.133560 end 0.144898 avg 0.139229 mfcc_st 1479 mfcc_end 1605
# swap deviation q 3 ref 7 : st 0.092381 end 0.096009 avg 0.094195 mfcc_st 1014 mfcc_end 1054
# Doing for q: 8
# normal deviation q 8 ref 3 : st 0.129116 end 0.129206 avg 0.129161 mfcc_st 1422 mfcc_end 1423
# swap deviation q 3 ref 8 : st 0.112880 end 0.112971 avg 0.112925 mfcc_st 1243 mfcc_end 1244
# Doing for q: 9
# normal deviation q 9 ref 3 : st 0.166304 end 0.166395 avg 0.166349 mfcc_st 1834 mfcc_end 1835
# swap deviation q 3 ref 9 : st 0.198957 end 0.199048 avg 0.199002 mfcc_st 2192 mfcc_end 2193
# Doing for q: 10
# normal deviation q 10 ref 3 : st 0.130748 end 0.130884 avg 0.130816 mfcc_st 1436 mfcc_end 1438
# swap deviation q 3 ref 10 : st 0.132472 end 0.132744 avg 0.132608 mfcc_st 1467 mfcc_end 1470
# Doing for q: 11
# normal deviation q 11 ref 3 : st 0.160272 end 0.160363 avg 0.160317 mfcc_st 1759 mfcc_end 1760
# swap deviation q 3 ref 11 : st 0.104263 end 0.104354 avg 0.104308 mfcc_st 1143 mfcc_end 1144
# Doing for q: 12
# normal deviation q 12 ref 3 : st 0.100544 end 0.100635 avg 0.100590 mfcc_st 1117 mfcc_end 1118
# swap deviation q 3 ref 12 : st 0.101995 end 0.102086 avg 0.102041 mfcc_st 1125 mfcc_end 1126
# Doing for q: 13
# normal deviation q 13 ref 3 : st 0.254059 end 0.254150 avg 0.254104 mfcc_st 2806 mfcc_end 2807
# swap deviation q 3 ref 13 : st 0.149705 end 0.149796 avg 0.149751 mfcc_st 1649 mfcc_end 1650
# Doing for r: 4
# Doing for q: 5
# normal deviation q 5 ref 4 : st 0.258050 end 0.258141 avg 0.258095 mfcc_st 2856 mfcc_end 2857
# swap deviation q 4 ref 5 : st 0.285170 end 0.285261 avg 0.285215 mfcc_st 3134 mfcc_end 3135
# Doing for q: 6
# normal deviation q 6 ref 4 : st 0.452517 end 0.452608 avg 0.452562 mfcc_st 4984 mfcc_end 4985
# swap deviation q 4 ref 6 : st 0.391927 end 0.392018 avg 0.391973 mfcc_st 4319 mfcc_end 4320
# Doing for q: 7
# normal deviation q 7 ref 4 : st 0.224082 end 0.235601 avg 0.229841 mfcc_st 2486 mfcc_end 2614
# swap deviation q 4 ref 7 : st 0.358458 end 0.368345 avg 0.363401 mfcc_st 3932 mfcc_end 4041
# Doing for q: 8
# normal deviation q 8 ref 4 : st 0.713333 end 0.713424 avg 0.713379 mfcc_st 7863 mfcc_end 7864
# swap deviation q 4 ref 8 : st 1.111383 end 1.111474 avg 1.111429 mfcc_st 12257 mfcc_end 12258
# Doing for q: 9
# normal deviation q 9 ref 4 : st 0.114875 end 0.114966 avg 0.114921 mfcc_st 1263 mfcc_end 1264
# swap deviation q 4 ref 9 : st 0.214512 end 0.214603 avg 0.214558 mfcc_st 2357 mfcc_end 2358
# Doing for q: 10
# normal deviation q 10 ref 4 : st 0.407846 end 0.407982 avg 0.407914 mfcc_st 4497 mfcc_end 4499
# swap deviation q 4 ref 10 : st 0.634921 end 0.635193 avg 0.635057 mfcc_st 7002 mfcc_end 7005
# Doing for q: 11
# normal deviation q 11 ref 4 : st 0.129342 end 0.129433 avg 0.129388 mfcc_st 1428 mfcc_end 1429
# swap deviation q 4 ref 11 : st 0.207982 end 0.208073 avg 0.208027 mfcc_st 2293 mfcc_end 2294
# Doing for q: 12
# normal deviation q 12 ref 4 : st 0.473787 end 0.473878 avg 0.473832 mfcc_st 5225 mfcc_end 5226
# swap deviation q 4 ref 12 : st 0.749297 end 0.749388 avg 0.749342 mfcc_st 8263 mfcc_end 8264
# Doing for q: 13
# normal deviation q 13 ref 4 : st 0.257324 end 0.257415 avg 0.257370 mfcc_st 2837 mfcc_end 2838
# swap deviation q 4 ref 13 : st 0.257596 end 0.257687 avg 0.257642 mfcc_st 2846 mfcc_end 2847
# Doing for r: 5
# Doing for q: 6
# normal deviation q 6 ref 5 : st 0.610884 end 0.610975 avg 0.610930 mfcc_st 6723 mfcc_end 6724
# swap deviation q 5 ref 6 : st 0.464853 end 0.464943 avg 0.464898 mfcc_st 5127 mfcc_end 5128
# Doing for q: 7
# normal deviation q 7 ref 5 : st 0.274059 end 0.294286 avg 0.284172 mfcc_st 3027 mfcc_end 3251
# swap deviation q 5 ref 7 : st 0.287710 end 0.308481 avg 0.298095 mfcc_st 3173 mfcc_end 3402
# Doing for q: 8
# normal deviation q 8 ref 5 : st 0.175556 end 0.175646 avg 0.175601 mfcc_st 1932 mfcc_end 1933
# swap deviation q 5 ref 8 : st 0.228209 end 0.228299 avg 0.228254 mfcc_st 2527 mfcc_end 2528
# Doing for q: 9
# normal deviation q 9 ref 5 : st 0.131746 end 0.131837 avg 0.131791 mfcc_st 1444 mfcc_end 1445
# swap deviation q 5 ref 9 : st 0.238367 end 0.238458 avg 0.238413 mfcc_st 2633 mfcc_end 2634
# Doing for q: 10
# normal deviation q 10 ref 5 : st 0.158503 end 0.158639 avg 0.158571 mfcc_st 1740 mfcc_end 1742
# swap deviation q 5 ref 10 : st 0.227302 end 0.227574 avg 0.227438 mfcc_st 2524 mfcc_end 2527
# Doing for q: 11
# normal deviation q 11 ref 5 : st 0.214331 end 0.214422 avg 0.214376 mfcc_st 2360 mfcc_end 2361
# swap deviation q 5 ref 11 : st 0.253878 end 0.253968 avg 0.253923 mfcc_st 2815 mfcc_end 2816
# Doing for q: 12
# normal deviation q 12 ref 5 : st 0.157052 end 0.157143 avg 0.157098 mfcc_st 1733 mfcc_end 1734
# swap deviation q 5 ref 12 : st 0.213152 end 0.213243 avg 0.213197 mfcc_st 2366 mfcc_end 2367
# Doing for q: 13
# normal deviation q 13 ref 5 : st 0.226213 end 0.226304 avg 0.226259 mfcc_st 2495 mfcc_end 2496
# swap deviation q 5 ref 13 : st 0.219683 end 0.219773 avg 0.219728 mfcc_st 2429 mfcc_end 2430
# Doing for r: 6
# Doing for q: 7
# normal deviation q 7 ref 6 : st 0.142449 end 0.126213 avg 0.134331 mfcc_st 1566 mfcc_end 1388
# swap deviation q 6 ref 7 : st 0.356009 end 0.350748 avg 0.353379 mfcc_st 3914 mfcc_end 3856
# Doing for q: 8
# normal deviation q 8 ref 6 : st 0.253469 end 0.253560 avg 0.253515 mfcc_st 2784 mfcc_end 2785
# swap deviation q 6 ref 8 : st 0.442177 end 0.442268 avg 0.442222 mfcc_st 4890 mfcc_end 4891
# Doing for q: 9
# normal deviation q 9 ref 6 : st 0.318685 end 0.318776 avg 0.318730 mfcc_st 3513 mfcc_end 3514
# swap deviation q 6 ref 9 : st 0.655510 end 0.655601 avg 0.655556 mfcc_st 7228 mfcc_end 7229
# Doing for q: 10
# normal deviation q 10 ref 6 : st 0.202041 end 0.202177 avg 0.202109 mfcc_st 2221 mfcc_end 2223
# swap deviation q 6 ref 10 : st 0.431383 end 0.431655 avg 0.431519 mfcc_st 4760 mfcc_end 4763
# Doing for q: 11
# normal deviation q 11 ref 6 : st 0.124807 end 0.124898 avg 0.124853 mfcc_st 1367 mfcc_end 1368
# swap deviation q 6 ref 11 : st 0.336417 end 0.336508 avg 0.336463 mfcc_st 3734 mfcc_end 3735
# Doing for q: 12
# normal deviation q 12 ref 6 : st 0.210839 end 0.210930 avg 0.210884 mfcc_st 2324 mfcc_end 2325
# swap deviation q 6 ref 12 : st 0.441814 end 0.441905 avg 0.441859 mfcc_st 4850 mfcc_end 4851
# Doing for q: 13
# normal deviation q 13 ref 6 : st 0.367710 end 0.367800 avg 0.367755 mfcc_st 4051 mfcc_end 4052
# swap deviation q 6 ref 13 : st 0.482177 end 0.482268 avg 0.482222 mfcc_st 5328 mfcc_end 5329
# Doing for r: 7
# Doing for q: 8
# normal deviation q 8 ref 7 : st 0.126576 end 0.128027 avg 0.127302 mfcc_st 1391 mfcc_end 1407
# swap deviation q 7 ref 8 : st 0.128299 end 0.136372 avg 0.132336 mfcc_st 1420 mfcc_end 1510
# Doing for q: 9
# normal deviation q 9 ref 7 : st 0.124762 end 0.114785 avg 0.119773 mfcc_st 1368 mfcc_end 1258
# swap deviation q 7 ref 9 : st 0.192426 end 0.172109 avg 0.182268 mfcc_st 2132 mfcc_end 1908
# Doing for q: 10
# normal deviation q 10 ref 7 : st 0.123673 end 0.133515 avg 0.128594 mfcc_st 1357 mfcc_end 1466
# swap deviation q 7 ref 10 : st 0.155057 end 0.175556 avg 0.165306 mfcc_st 1722 mfcc_end 1948
# Doing for q: 11
# normal deviation q 11 ref 7 : st 0.198912 end 0.221497 avg 0.210204 mfcc_st 2180 mfcc_end 2429
# swap deviation q 7 ref 11 : st 0.214014 end 0.234512 avg 0.224263 mfcc_st 2375 mfcc_end 2601
# Doing for q: 12
# normal deviation q 12 ref 7 : st 0.099909 end 0.100635 avg 0.100272 mfcc_st 1101 mfcc_end 1108
# swap deviation q 7 ref 12 : st 0.121224 end 0.110431 avg 0.115828 mfcc_st 1344 mfcc_end 1226
# Doing for q: 13
# normal deviation q 13 ref 7 : st 0.272018 end 0.261315 avg 0.266667 mfcc_st 2996 mfcc_end 2878
# swap deviation q 7 ref 13 : st 0.222812 end 0.205669 avg 0.214240 mfcc_st 2464 mfcc_end 2276
# Doing for r: 8
# Doing for q: 9
# normal deviation q 9 ref 8 : st 0.113787 end 0.113878 avg 0.113832 mfcc_st 1254 mfcc_end 1255
# swap deviation q 8 ref 9 : st 0.143447 end 0.143537 avg 0.143492 mfcc_st 1578 mfcc_end 1579
# Doing for q: 10
# normal deviation q 10 ref 8 : st 0.085034 end 0.085170 avg 0.085102 mfcc_st 934 mfcc_end 936
# swap deviation q 8 ref 10 : st 0.092834 end 0.093107 avg 0.092971 mfcc_st 1027 mfcc_end 1030
# Doing for q: 11
# normal deviation q 11 ref 8 : st 0.134603 end 0.134694 avg 0.134649 mfcc_st 1493 mfcc_end 1494
# swap deviation q 8 ref 11 : st 0.141088 end 0.141179 avg 0.141134 mfcc_st 1554 mfcc_end 1555
# Doing for q: 12
# normal deviation q 12 ref 8 : st 0.100000 end 0.100091 avg 0.100045 mfcc_st 1104 mfcc_end 1105
# swap deviation q 8 ref 12 : st 0.106984 end 0.107075 avg 0.107029 mfcc_st 1180 mfcc_end 1181
# Doing for q: 13
# normal deviation q 13 ref 8 : st 0.148390 end 0.148481 avg 0.148435 mfcc_st 1643 mfcc_end 1644
# swap deviation q 8 ref 13 : st 0.121497 end 0.121587 avg 0.121542 mfcc_st 1334 mfcc_end 1335
# Doing for r: 9
# Doing for q: 10
# normal deviation q 10 ref 9 : st 0.117143 end 0.117279 avg 0.117211 mfcc_st 1287 mfcc_end 1289
# swap deviation q 9 ref 10 : st 0.098095 end 0.098277 avg 0.098186 mfcc_st 1086 mfcc_end 1088
# Doing for q: 11
# normal deviation q 11 ref 9 : st 0.178503 end 0.178594 avg 0.178549 mfcc_st 1970 mfcc_end 1971
# swap deviation q 9 ref 11 : st 0.112336 end 0.112426 avg 0.112381 mfcc_st 1241 mfcc_end 1242
# Doing for q: 12
# normal deviation q 12 ref 9 : st 0.132834 end 0.132925 avg 0.132880 mfcc_st 1457 mfcc_end 1458
# swap deviation q 9 ref 12 : st 0.107256 end 0.107347 avg 0.107302 mfcc_st 1188 mfcc_end 1189
# Doing for q: 13
# normal deviation q 13 ref 9 : st 0.248345 end 0.248435 avg 0.248390 mfcc_st 2741 mfcc_end 2742
# swap deviation q 9 ref 13 : st 0.100272 end 0.100363 avg 0.100317 mfcc_st 1099 mfcc_end 1100
# Doing for r: 10
# Doing for q: 11
# normal deviation q 11 ref 10 : st 0.138413 end 0.138685 avg 0.138549 mfcc_st 1528 mfcc_end 1531
# swap deviation q 10 ref 11 : st 0.109887 end 0.110023 avg 0.109955 mfcc_st 1209 mfcc_end 1211
# Doing for q: 12
# normal deviation q 12 ref 10 : st 0.097914 end 0.098186 avg 0.098050 mfcc_st 1091 mfcc_end 1094
# swap deviation q 10 ref 12 : st 0.102268 end 0.102404 avg 0.102336 mfcc_st 1119 mfcc_end 1121
# Doing for q: 13
# normal deviation q 13 ref 10 : st 0.149841 end 0.150113 avg 0.149977 mfcc_st 1656 mfcc_end 1659
# swap deviation q 10 ref 13 : st 0.087211 end 0.087347 avg 0.087279 mfcc_st 962 mfcc_end 964
# Doing for r: 11
# Doing for q: 12
# normal deviation q 12 ref 11 : st 0.117959 end 0.118050 avg 0.118005 mfcc_st 1307 mfcc_end 1308
# swap deviation q 11 ref 12 : st 0.155102 end 0.155193 avg 0.155147 mfcc_st 1704 mfcc_end 1705
# Doing for q: 13
# normal deviation q 13 ref 11 : st 0.204082 end 0.204172 avg 0.204127 mfcc_st 2253 mfcc_end 2254
# swap deviation q 11 ref 13 : st 0.136417 end 0.136508 avg 0.136463 mfcc_st 1502 mfcc_end 1503
# Doing for r: 12
# Doing for q: 13
# normal deviation q 13 ref 12 : st 0.227846 end 0.227937 avg 0.227891 mfcc_st 2516 mfcc_end 2517
# swap deviation q 12 ref 13 : st 0.126757 end 0.126848 avg 0.126803 mfcc_st 1399 mfcc_end 1400
# Doing for r: 13

# %%
dev_for_ref/len(at_a_arr)
# Out:
# array([0.17207159, 0.26950761, 0.20834467, 2.5084872 , 1.77275024,
#        0.22668934, 0.2721056 , 0.20295432, 0.21681568, 0.21564302,
#        0.19016359, 0.16601879, 0.22535147, 0.16718173])

# %% [markdown]
# Checking if the warping path has been dumped correctly.
# Reading from the bin file and seeing that the deviation values asre the same.

# %%
dev_for_ref = np.zeros(len(at_a_arr), dtype=float)
cnt_for_ref = np.zeros(len(at_a_arr), dtype=int)

for r_idx in range(0, len(at_a_arr)):
    print("Checking for r:", r_idx)
    for q_idx in range(r_idx+1, len(at_a_arr)):
        print("Checking for q:", q_idx)
        ap_a_b = g_a.alignment_pair(at_a_arr[q_idx], at_a_arr[r_idx])
        ap_a_b.set_warping_path(r"C:\Users\Lenovo\Desktop\sishya\prints\aeneas_stripe\%d_%d.bin" %(q_idx, r_idx))
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_a_b.get_alignment_deviation_normal()
        st_diff = st_diff / len(ap_a_b.query_audio.labels)
        end_diff = end_diff / len(ap_a_b.query_audio.labels)
        
        print("normal deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(q_idx, r_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[r_idx] += (st_diff+end_diff)/2
        cnt_for_ref[r_idx] += 1
        
        st_diff, end_diff, st_diff_mfcc, end_diff_mfcc = ap_a_b.get_alignment_deviation_swap()

        st_diff = st_diff / len(ap_a.ref_audio.labels)
        end_diff = end_diff / len(ap_a.ref_audio.labels)
        
        print("swap deviation q %d ref %d : st %f end %f avg %f mfcc_st %d mfcc_end %d" 
            %(r_idx, q_idx, st_diff, end_diff, (st_diff+end_diff)/2, st_diff_mfcc, end_diff_mfcc))
        dev_for_ref[q_idx] += (st_diff+end_diff)/2
        cnt_for_ref[q_idx] += 1
# Out:
# Checking for r: 0
# Checking for q: 1
# 34360
# normal deviation q 1 ref 0 : st 0.198685 end 0.200227 avg 0.199456 mfcc_st 2188 mfcc_end 2205
# swap deviation q 0 ref 1 : st 0.111519 end 0.118912 avg 0.115215 mfcc_st 1233 mfcc_end 1315
# Checking for q: 2
# 35019
# normal deviation q 2 ref 0 : st 0.204399 end 0.227891 avg 0.216145 mfcc_st 2261 mfcc_end 2521
# swap deviation q 0 ref 2 : st 0.155601 end 0.187574 avg 0.171587 mfcc_st 1709 mfcc_end 2062
# Checking for q: 3
# 33071
# normal deviation q 3 ref 0 : st 0.137007 end 0.137279 avg 0.137143 mfcc_st 1507 mfcc_end 1510
# swap deviation q 0 ref 3 : st 0.184082 end 0.191474 avg 0.187778 mfcc_st 2025 mfcc_end 2107
# Checking for q: 4
# 40208
# normal deviation q 4 ref 0 : st 0.208798 end 0.212698 avg 0.210748 mfcc_st 2303 mfcc_end 2346
# swap deviation q 0 ref 4 : st 0.144717 end 0.152109 avg 0.148413 mfcc_st 1588 mfcc_end 1670
# Checking for q: 5
# 34162
# normal deviation q 5 ref 0 : st 0.223220 end 0.228753 avg 0.225986 mfcc_st 2474 mfcc_end 2535
# swap deviation q 0 ref 5 : st 0.179456 end 0.186848 avg 0.183152 mfcc_st 1969 mfcc_end 2051
# Checking for q: 6
# 41025
# normal deviation q 6 ref 0 : st 0.549297 end 0.553107 avg 0.551202 mfcc_st 6051 mfcc_end 6093
# swap deviation q 0 ref 6 : st 0.382993 end 0.390385 avg 0.386689 mfcc_st 4216 mfcc_end 4298
# Checking for q: 7
# 32502
# normal deviation q 7 ref 0 : st 0.162494 end 0.174830 avg 0.168662 mfcc_st 1801 mfcc_end 1938
# swap deviation q 0 ref 7 : st 0.169025 end 0.180680 avg 0.174853 mfcc_st 1857 mfcc_end 1986
# Checking for q: 8
# 31780
# normal deviation q 8 ref 0 : st 0.089660 end 0.090113 avg 0.089887 mfcc_st 990 mfcc_end 995
# swap deviation q 0 ref 8 : st 0.089841 end 0.097234 avg 0.093537 mfcc_st 992 mfcc_end 1074
# Checking for q: 9
# 31638
# normal deviation q 9 ref 0 : st 0.103991 end 0.106531 avg 0.105261 mfcc_st 1149 mfcc_end 1177
# swap deviation q 0 ref 9 : st 0.162313 end 0.169705 avg 0.166009 mfcc_st 1787 mfcc_end 1869
# Checking for q: 10
# 31366
# normal deviation q 10 ref 0 : st 0.070794 end 0.072653 avg 0.071723 mfcc_st 779 mfcc_end 799
# swap deviation q 0 ref 10 : st 0.083220 end 0.090431 avg 0.086825 mfcc_st 917 mfcc_end 997
# Checking for q: 11
# 32992
# normal deviation q 11 ref 0 : st 0.120998 end 0.124444 avg 0.122721 mfcc_st 1332 mfcc_end 1370
# swap deviation q 0 ref 11 : st 0.125215 end 0.132608 avg 0.128912 mfcc_st 1377 mfcc_end 1459
# Checking for q: 12
# 32025
# normal deviation q 12 ref 0 : st 0.174195 end 0.174830 avg 0.174512 mfcc_st 1929 mfcc_end 1936
# swap deviation q 0 ref 12 : st 0.201315 end 0.208707 avg 0.205011 mfcc_st 2216 mfcc_end 2298
# Checking for q: 13
# 33922
# normal deviation q 13 ref 0 : st 0.135420 end 0.135692 avg 0.135556 mfcc_st 1500 mfcc_end 1503
# swap deviation q 0 ref 13 : st 0.085850 end 0.093243 avg 0.089546 mfcc_st 939 mfcc_end 1021
# Checking for r: 1
# Checking for q: 2
# 36862
# normal deviation q 2 ref 1 : st 0.367029 end 0.390703 avg 0.378866 mfcc_st 4057 mfcc_end 4319
# swap deviation q 1 ref 2 : st 0.384444 end 0.406757 avg 0.395601 mfcc_st 4238 mfcc_end 4484
# Checking for q: 3
# 33370
# normal deviation q 3 ref 1 : st 0.249841 end 0.249932 avg 0.249887 mfcc_st 2764 mfcc_end 2765
# swap deviation q 1 ref 3 : st 0.389070 end 0.389161 avg 0.389116 mfcc_st 4285 mfcc_end 4286
# Checking for q: 4
# 41563
# normal deviation q 4 ref 1 : st 0.565442 end 0.565533 avg 0.565488 mfcc_st 6235 mfcc_end 6236
# swap deviation q 1 ref 4 : st 0.431973 end 0.432063 avg 0.432018 mfcc_st 4759 mfcc_end 4760
# Checking for q: 5
# 34984
# normal deviation q 5 ref 1 : st 0.348934 end 0.349025 avg 0.348980 mfcc_st 3865 mfcc_end 3866
# swap deviation q 1 ref 5 : st 0.359501 end 0.359592 avg 0.359546 mfcc_st 3957 mfcc_end 3958
# Checking for q: 6
# 37856
# normal deviation q 6 ref 1 : st 0.566349 end 0.566440 avg 0.566395 mfcc_st 6252 mfcc_end 6253
# swap deviation q 1 ref 6 : st 0.427982 end 0.428073 avg 0.428027 mfcc_st 4712 mfcc_end 4713
# Checking for q: 7
# 31457
# normal deviation q 7 ref 1 : st 0.416916 end 0.437415 avg 0.427166 mfcc_st 4608 mfcc_end 4834
# swap deviation q 1 ref 7 : st 0.466531 end 0.488934 avg 0.477732 mfcc_st 5133 mfcc_end 5380
# Checking for q: 8
# 30806
# normal deviation q 8 ref 1 : st 0.151156 end 0.151247 avg 0.151202 mfcc_st 1664 mfcc_end 1665
# swap deviation q 1 ref 8 : st 0.207211 end 0.207302 avg 0.207256 mfcc_st 2287 mfcc_end 2288
# Checking for q: 9
# 30394
# normal deviation q 9 ref 1 : st 0.142449 end 0.142540 avg 0.142494 mfcc_st 1577 mfcc_end 1578
# swap deviation q 1 ref 9 : st 0.266077 end 0.266168 avg 0.266122 mfcc_st 2928 mfcc_end 2929
# Checking for q: 10
# 30861
# normal deviation q 10 ref 1 : st 0.146893 end 0.147029 avg 0.146961 mfcc_st 1622 mfcc_end 1624
# swap deviation q 1 ref 10 : st 0.246667 end 0.246939 avg 0.246803 mfcc_st 2721 mfcc_end 2724
# Checking for q: 11
# 33210
# normal deviation q 11 ref 1 : st 0.134694 end 0.134785 avg 0.134739 mfcc_st 1486 mfcc_end 1487
# swap deviation q 1 ref 11 : st 0.208209 end 0.208299 avg 0.208254 mfcc_st 2296 mfcc_end 2297
# Checking for q: 12
# 31713
# normal deviation q 12 ref 1 : st 0.378549 end 0.378639 avg 0.378594 mfcc_st 4185 mfcc_end 4186
# swap deviation q 1 ref 12 : st 0.467528 end 0.467619 avg 0.467574 mfcc_st 5152 mfcc_end 5153
# Checking for q: 13
# 32443
# normal deviation q 13 ref 1 : st 0.167075 end 0.167166 avg 0.167120 mfcc_st 1850 mfcc_end 1851
# swap deviation q 1 ref 13 : st 0.183810 end 0.183900 avg 0.183855 mfcc_st 2013 mfcc_end 2014
# Checking for r: 2
# Checking for q: 3
# 32640
# normal deviation q 3 ref 2 : st 0.111882 end 0.114150 avg 0.113016 mfcc_st 1230 mfcc_end 1255
# swap deviation q 2 ref 3 : st 0.123946 end 0.147438 avg 0.135692 mfcc_st 1374 mfcc_end 1634
# Checking for q: 4
# 41707
# normal deviation q 4 ref 2 : st 0.567075 end 0.571973 avg 0.569524 mfcc_st 6258 mfcc_end 6312
# swap deviation q 2 ref 4 : st 0.427166 end 0.452200 avg 0.439683 mfcc_st 4710 mfcc_end 4986
# Checking for q: 5
# 34994
# normal deviation q 5 ref 2 : st 0.230385 end 0.229025 avg 0.229705 mfcc_st 2549 mfcc_end 2534
# swap deviation q 2 ref 5 : st 0.218549 end 0.221723 avg 0.220136 mfcc_st 2399 mfcc_end 2435
# Checking for q: 6
# 42455
# normal deviation q 6 ref 2 : st 0.475193 end 0.472018 avg 0.473605 mfcc_st 5227 mfcc_end 5192
# swap deviation q 2 ref 6 : st 0.302721 end 0.284853 avg 0.293787 mfcc_st 3333 mfcc_end 3137
# Checking for q: 7
# 32795
# normal deviation q 7 ref 2 : st 0.130748 end 0.130204 avg 0.130476 mfcc_st 1443 mfcc_end 1436
# swap deviation q 2 ref 7 : st 0.127120 end 0.126667 avg 0.126893 mfcc_st 1396 mfcc_end 1392
# Checking for q: 8
# 32523
# normal deviation q 8 ref 2 : st 0.108707 end 0.111519 avg 0.110113 mfcc_st 1193 mfcc_end 1224
# swap deviation q 2 ref 8 : st 0.112880 end 0.137914 avg 0.125397 mfcc_st 1244 mfcc_end 1520
# Checking for q: 9
# 32600
# normal deviation q 9 ref 2 : st 0.146349 end 0.153243 avg 0.149796 mfcc_st 1613 mfcc_end 1689
# swap deviation q 2 ref 9 : st 0.264989 end 0.288118 avg 0.276553 mfcc_st 2918 mfcc_end 3174
# Checking for q: 10
# 32150
# normal deviation q 10 ref 2 : st 0.110159 end 0.115828 avg 0.112993 mfcc_st 1214 mfcc_end 1277
# swap deviation q 2 ref 10 : st 0.147347 end 0.170658 avg 0.159002 mfcc_st 1634 mfcc_end 1892
# Checking for q: 11
# 34588
# normal deviation q 11 ref 2 : st 0.166893 end 0.174150 avg 0.170522 mfcc_st 1832 mfcc_end 1912
# swap deviation q 2 ref 11 : st 0.162585 end 0.186440 avg 0.174512 mfcc_st 1796 mfcc_end 2060
# Checking for q: 12
# 31933
# normal deviation q 12 ref 2 : st 0.110794 end 0.112426 avg 0.111610 mfcc_st 1228 mfcc_end 1245
# swap deviation q 2 ref 12 : st 0.155238 end 0.165488 avg 0.160363 mfcc_st 1708 mfcc_end 1822
# Checking for q: 13
# 35550
# normal deviation q 13 ref 2 : st 0.178594 end 0.177959 avg 0.178277 mfcc_st 1968 mfcc_end 1961
# swap deviation q 2 ref 13 : st 0.180181 end 0.162132 avg 0.171156 mfcc_st 1994 mfcc_end 1796
# Checking for r: 3
# Checking for q: 4
# 46123
# normal deviation q 4 ref 3 : st 32.530703 end 32.530794 avg 32.530748 mfcc_st 358666 mfcc_end 358667
# swap deviation q 3 ref 4 : st 20.761043 end 20.761134 avg 20.761088 mfcc_st 228872 mfcc_end 228873
# Checking for q: 5
# 32415
# normal deviation q 5 ref 3 : st 0.237551 end 0.237642 avg 0.237596 mfcc_st 2631 mfcc_end 2632
# swap deviation q 3 ref 5 : st 0.166757 end 0.166848 avg 0.166803 mfcc_st 1826 mfcc_end 1827
# Checking for q: 6
# 38250
# normal deviation q 6 ref 3 : st 0.557279 end 0.557370 avg 0.557324 mfcc_st 6130 mfcc_end 6131
# swap deviation q 3 ref 6 : st 0.231882 end 0.231973 avg 0.231927 mfcc_st 2552 mfcc_end 2553
# Checking for q: 7
# 28918
# normal deviation q 7 ref 3 : st 0.133560 end 0.144898 avg 0.139229 mfcc_st 1479 mfcc_end 1605
# swap deviation q 3 ref 7 : st 0.092381 end 0.096009 avg 0.094195 mfcc_st 1014 mfcc_end 1054
# Checking for q: 8
# 28020
# normal deviation q 8 ref 3 : st 0.129116 end 0.129206 avg 0.129161 mfcc_st 1422 mfcc_end 1423
# swap deviation q 3 ref 8 : st 0.112880 end 0.112971 avg 0.112925 mfcc_st 1243 mfcc_end 1244
# Checking for q: 9
# 26969
# normal deviation q 9 ref 3 : st 0.166304 end 0.166395 avg 0.166349 mfcc_st 1834 mfcc_end 1835
# swap deviation q 3 ref 9 : st 0.198957 end 0.199048 avg 0.199002 mfcc_st 2192 mfcc_end 2193
# Checking for q: 10
# 27624
# normal deviation q 10 ref 3 : st 0.130748 end 0.130884 avg 0.130816 mfcc_st 1436 mfcc_end 1438
# swap deviation q 3 ref 10 : st 0.132472 end 0.132744 avg 0.132608 mfcc_st 1467 mfcc_end 1470
# Checking for q: 11
# 30997
# normal deviation q 11 ref 3 : st 0.160272 end 0.160363 avg 0.160317 mfcc_st 1759 mfcc_end 1760
# swap deviation q 3 ref 11 : st 0.104263 end 0.104354 avg 0.104308 mfcc_st 1143 mfcc_end 1144
# Checking for q: 12
# 26698
# normal deviation q 12 ref 3 : st 0.100544 end 0.100635 avg 0.100590 mfcc_st 1117 mfcc_end 1118
# swap deviation q 3 ref 12 : st 0.101995 end 0.102086 avg 0.102041 mfcc_st 1125 mfcc_end 1126
# Checking for q: 13
# 32118
# normal deviation q 13 ref 3 : st 0.254059 end 0.254150 avg 0.254104 mfcc_st 2806 mfcc_end 2807
# swap deviation q 3 ref 13 : st 0.149705 end 0.149796 avg 0.149751 mfcc_st 1649 mfcc_end 1650
# Checking for r: 4
# Checking for q: 5
# 41260
# normal deviation q 5 ref 4 : st 0.258050 end 0.258141 avg 0.258095 mfcc_st 2856 mfcc_end 2857
# swap deviation q 4 ref 5 : st 0.285170 end 0.285261 avg 0.285215 mfcc_st 3134 mfcc_end 3135
# Checking for q: 6
# 45669
# normal deviation q 6 ref 4 : st 0.452517 end 0.452608 avg 0.452562 mfcc_st 4984 mfcc_end 4985
# swap deviation q 4 ref 6 : st 0.391927 end 0.392018 avg 0.391973 mfcc_st 4319 mfcc_end 4320
# Checking for q: 7
# 39948
# normal deviation q 7 ref 4 : st 0.224082 end 0.235601 avg 0.229841 mfcc_st 2486 mfcc_end 2614
# swap deviation q 4 ref 7 : st 0.358458 end 0.368345 avg 0.363401 mfcc_st 3932 mfcc_end 4041
# Checking for q: 8
# 41529
# normal deviation q 8 ref 4 : st 0.713333 end 0.713424 avg 0.713379 mfcc_st 7863 mfcc_end 7864
# swap deviation q 4 ref 8 : st 1.111383 end 1.111474 avg 1.111429 mfcc_st 12257 mfcc_end 12258
# Checking for q: 9
# 39563
# normal deviation q 9 ref 4 : st 0.114875 end 0.114966 avg 0.114921 mfcc_st 1263 mfcc_end 1264
# swap deviation q 4 ref 9 : st 0.214512 end 0.214603 avg 0.214558 mfcc_st 2357 mfcc_end 2358
# Checking for q: 10
# 40296
# normal deviation q 10 ref 4 : st 0.407846 end 0.407982 avg 0.407914 mfcc_st 4497 mfcc_end 4499
# swap deviation q 4 ref 10 : st 0.634921 end 0.635193 avg 0.635057 mfcc_st 7002 mfcc_end 7005
# Checking for q: 11
# 39711
# normal deviation q 11 ref 4 : st 0.129342 end 0.129433 avg 0.129388 mfcc_st 1428 mfcc_end 1429
# swap deviation q 4 ref 11 : st 0.207982 end 0.208073 avg 0.208027 mfcc_st 2293 mfcc_end 2294
# Checking for q: 12
# 40423
# normal deviation q 12 ref 4 : st 0.473787 end 0.473878 avg 0.473832 mfcc_st 5225 mfcc_end 5226
# swap deviation q 4 ref 12 : st 0.749297 end 0.749388 avg 0.749342 mfcc_st 8263 mfcc_end 8264
# Checking for q: 13
# 41906
# normal deviation q 13 ref 4 : st 0.257324 end 0.257415 avg 0.257370 mfcc_st 2837 mfcc_end 2838
# swap deviation q 4 ref 13 : st 0.257596 end 0.257687 avg 0.257642 mfcc_st 2846 mfcc_end 2847
# Checking for r: 5
# Checking for q: 6
# 43315
# normal deviation q 6 ref 5 : st 0.610884 end 0.610975 avg 0.610930 mfcc_st 6723 mfcc_end 6724
# swap deviation q 5 ref 6 : st 0.464853 end 0.464943 avg 0.464898 mfcc_st 5127 mfcc_end 5128
# Checking for q: 7
# 33728
# normal deviation q 7 ref 5 : st 0.274059 end 0.294286 avg 0.284172 mfcc_st 3027 mfcc_end 3251
# swap deviation q 5 ref 7 : st 0.287710 end 0.308481 avg 0.298095 mfcc_st 3173 mfcc_end 3402
# Checking for q: 8
# 31898
# normal deviation q 8 ref 5 : st 0.175556 end 0.175646 avg 0.175601 mfcc_st 1932 mfcc_end 1933
# swap deviation q 5 ref 8 : st 0.228209 end 0.228299 avg 0.228254 mfcc_st 2527 mfcc_end 2528
# Checking for q: 9
# 31362
# normal deviation q 9 ref 5 : st 0.131746 end 0.131837 avg 0.131791 mfcc_st 1444 mfcc_end 1445
# swap deviation q 5 ref 9 : st 0.238367 end 0.238458 avg 0.238413 mfcc_st 2633 mfcc_end 2634
# Checking for q: 10
# 31464
# normal deviation q 10 ref 5 : st 0.158503 end 0.158639 avg 0.158571 mfcc_st 1740 mfcc_end 1742
# swap deviation q 5 ref 10 : st 0.227302 end 0.227574 avg 0.227438 mfcc_st 2524 mfcc_end 2527
# Checking for q: 11
# 34549
# normal deviation q 11 ref 5 : st 0.214331 end 0.214422 avg 0.214376 mfcc_st 2360 mfcc_end 2361
# swap deviation q 5 ref 11 : st 0.253878 end 0.253968 avg 0.253923 mfcc_st 2815 mfcc_end 2816
# Checking for q: 12
# 31381
# normal deviation q 12 ref 5 : st 0.157052 end 0.157143 avg 0.157098 mfcc_st 1733 mfcc_end 1734
# swap deviation q 5 ref 12 : st 0.213152 end 0.213243 avg 0.213197 mfcc_st 2366 mfcc_end 2367
# Checking for q: 13
# 33136
# normal deviation q 13 ref 5 : st 0.226213 end 0.226304 avg 0.226259 mfcc_st 2495 mfcc_end 2496
# swap deviation q 5 ref 13 : st 0.219683 end 0.219773 avg 0.219728 mfcc_st 2429 mfcc_end 2430
# Checking for r: 6
# Checking for q: 7
# 36309
# normal deviation q 7 ref 6 : st 0.142449 end 0.126213 avg 0.134331 mfcc_st 1566 mfcc_end 1388
# swap deviation q 6 ref 7 : st 0.356009 end 0.350748 avg 0.353379 mfcc_st 3914 mfcc_end 3856
# Checking for q: 8
# 37704
# normal deviation q 8 ref 6 : st 0.253469 end 0.253560 avg 0.253515 mfcc_st 2784 mfcc_end 2785
# swap deviation q 6 ref 8 : st 0.442177 end 0.442268 avg 0.442222 mfcc_st 4890 mfcc_end 4891
# Checking for q: 9
# 37371
# normal deviation q 9 ref 6 : st 0.318685 end 0.318776 avg 0.318730 mfcc_st 3513 mfcc_end 3514
# swap deviation q 6 ref 9 : st 0.655510 end 0.655601 avg 0.655556 mfcc_st 7228 mfcc_end 7229
# Checking for q: 10
# 37374
# normal deviation q 10 ref 6 : st 0.202041 end 0.202177 avg 0.202109 mfcc_st 2221 mfcc_end 2223
# swap deviation q 6 ref 10 : st 0.431383 end 0.431655 avg 0.431519 mfcc_st 4760 mfcc_end 4763
# Checking for q: 11
# 37424
# normal deviation q 11 ref 6 : st 0.124807 end 0.124898 avg 0.124853 mfcc_st 1367 mfcc_end 1368
# swap deviation q 6 ref 11 : st 0.336417 end 0.336508 avg 0.336463 mfcc_st 3734 mfcc_end 3735
# Checking for q: 12
# 36989
# normal deviation q 12 ref 6 : st 0.210839 end 0.210930 avg 0.210884 mfcc_st 2324 mfcc_end 2325
# swap deviation q 6 ref 12 : st 0.441814 end 0.441905 avg 0.441859 mfcc_st 4850 mfcc_end 4851
# Checking for q: 13
# 38458
# normal deviation q 13 ref 6 : st 0.367710 end 0.367800 avg 0.367755 mfcc_st 4051 mfcc_end 4052
# swap deviation q 6 ref 13 : st 0.482177 end 0.482268 avg 0.482222 mfcc_st 5328 mfcc_end 5329
# Checking for r: 7
# Checking for q: 8
# 28330
# normal deviation q 8 ref 7 : st 0.126576 end 0.128027 avg 0.127302 mfcc_st 1391 mfcc_end 1407
# swap deviation q 7 ref 8 : st 0.128299 end 0.136372 avg 0.132336 mfcc_st 1420 mfcc_end 1510
# Checking for q: 9
# 27861
# normal deviation q 9 ref 7 : st 0.124762 end 0.114785 avg 0.119773 mfcc_st 1368 mfcc_end 1258
# swap deviation q 7 ref 9 : st 0.192426 end 0.172109 avg 0.182268 mfcc_st 2132 mfcc_end 1908
# Checking for q: 10
# 28072
# normal deviation q 10 ref 7 : st 0.123673 end 0.133515 avg 0.128594 mfcc_st 1357 mfcc_end 1466
# swap deviation q 7 ref 10 : st 0.155057 end 0.175556 avg 0.165306 mfcc_st 1722 mfcc_end 1948
# Checking for q: 11
# 30081
# normal deviation q 11 ref 7 : st 0.198912 end 0.221497 avg 0.210204 mfcc_st 2180 mfcc_end 2429
# swap deviation q 7 ref 11 : st 0.214014 end 0.234512 avg 0.224263 mfcc_st 2375 mfcc_end 2601
# Checking for q: 12
# 27578
# normal deviation q 12 ref 7 : st 0.099909 end 0.100635 avg 0.100272 mfcc_st 1101 mfcc_end 1108
# swap deviation q 7 ref 12 : st 0.121224 end 0.110431 avg 0.115828 mfcc_st 1344 mfcc_end 1226
# Checking for q: 13
# 31562
# normal deviation q 13 ref 7 : st 0.272018 end 0.261315 avg 0.266667 mfcc_st 2996 mfcc_end 2878
# swap deviation q 7 ref 13 : st 0.222812 end 0.205669 avg 0.214240 mfcc_st 2464 mfcc_end 2276
# Checking for r: 8
# Checking for q: 9
# 26995
# normal deviation q 9 ref 8 : st 0.113787 end 0.113878 avg 0.113832 mfcc_st 1254 mfcc_end 1255
# swap deviation q 8 ref 9 : st 0.143447 end 0.143537 avg 0.143492 mfcc_st 1578 mfcc_end 1579
# Checking for q: 10
# 26931
# normal deviation q 10 ref 8 : st 0.085034 end 0.085170 avg 0.085102 mfcc_st 934 mfcc_end 936
# swap deviation q 8 ref 10 : st 0.092834 end 0.093107 avg 0.092971 mfcc_st 1027 mfcc_end 1030
# Checking for q: 11
# 30819
# normal deviation q 11 ref 8 : st 0.134603 end 0.134694 avg 0.134649 mfcc_st 1493 mfcc_end 1494
# swap deviation q 8 ref 11 : st 0.141088 end 0.141179 avg 0.141134 mfcc_st 1554 mfcc_end 1555
# Checking for q: 12
# 26796
# normal deviation q 12 ref 8 : st 0.100000 end 0.100091 avg 0.100045 mfcc_st 1104 mfcc_end 1105
# swap deviation q 8 ref 12 : st 0.106984 end 0.107075 avg 0.107029 mfcc_st 1180 mfcc_end 1181
# Checking for q: 13
# 31452
# normal deviation q 13 ref 8 : st 0.148390 end 0.148481 avg 0.148435 mfcc_st 1643 mfcc_end 1644
# swap deviation q 8 ref 13 : st 0.121497 end 0.121587 avg 0.121542 mfcc_st 1334 mfcc_end 1335
# Checking for r: 9
# Checking for q: 10
# 26428
# normal deviation q 10 ref 9 : st 0.117143 end 0.117279 avg 0.117211 mfcc_st 1287 mfcc_end 1289
# swap deviation q 9 ref 10 : st 0.098095 end 0.098277 avg 0.098186 mfcc_st 1086 mfcc_end 1088
# Checking for q: 11
# 29999
# normal deviation q 11 ref 9 : st 0.178503 end 0.178594 avg 0.178549 mfcc_st 1970 mfcc_end 1971
# swap deviation q 9 ref 11 : st 0.112336 end 0.112426 avg 0.112381 mfcc_st 1241 mfcc_end 1242
# Checking for q: 12
# 26526
# normal deviation q 12 ref 9 : st 0.132834 end 0.132925 avg 0.132880 mfcc_st 1457 mfcc_end 1458
# swap deviation q 9 ref 12 : st 0.107256 end 0.107347 avg 0.107302 mfcc_st 1188 mfcc_end 1189
# Checking for q: 13
# 30763
# normal deviation q 13 ref 9 : st 0.248345 end 0.248435 avg 0.248390 mfcc_st 2741 mfcc_end 2742
# swap deviation q 9 ref 13 : st 0.100272 end 0.100363 avg 0.100317 mfcc_st 1099 mfcc_end 1100
# Checking for r: 10
# Checking for q: 11
# 29949
# normal deviation q 11 ref 10 : st 0.138413 end 0.138685 avg 0.138549 mfcc_st 1528 mfcc_end 1531
# swap deviation q 10 ref 11 : st 0.109887 end 0.110023 avg 0.109955 mfcc_st 1209 mfcc_end 1211
# Checking for q: 12
# 26948
# normal deviation q 12 ref 10 : st 0.097914 end 0.098186 avg 0.098050 mfcc_st 1091 mfcc_end 1094
# swap deviation q 10 ref 12 : st 0.102268 end 0.102404 avg 0.102336 mfcc_st 1119 mfcc_end 1121
# Checking for q: 13
# 30948
# normal deviation q 13 ref 10 : st 0.149841 end 0.150113 avg 0.149977 mfcc_st 1656 mfcc_end 1659
# swap deviation q 10 ref 13 : st 0.087211 end 0.087347 avg 0.087279 mfcc_st 962 mfcc_end 964
# Checking for r: 11
# Checking for q: 12
# 29357
# normal deviation q 12 ref 11 : st 0.117959 end 0.118050 avg 0.118005 mfcc_st 1307 mfcc_end 1308
# swap deviation q 11 ref 12 : st 0.155102 end 0.155193 avg 0.155147 mfcc_st 1704 mfcc_end 1705
# Checking for q: 13
# 33209
# normal deviation q 13 ref 11 : st 0.204082 end 0.204172 avg 0.204127 mfcc_st 2253 mfcc_end 2254
# swap deviation q 11 ref 13 : st 0.136417 end 0.136508 avg 0.136463 mfcc_st 1502 mfcc_end 1503
# Checking for r: 12
# Checking for q: 13
# 31376
# normal deviation q 13 ref 12 : st 0.227846 end 0.227937 avg 0.227891 mfcc_st 2516 mfcc_end 2517
# swap deviation q 12 ref 13 : st 0.126757 end 0.126848 avg 0.126803 mfcc_st 1399 mfcc_end 1400
# Checking for r: 13

# %%
dev_for_ref/len(at_a_arr)
# Out:
# array([0.17207159, 0.26950761, 0.20834467, 2.5084872 , 1.77275024,
#        0.22668934, 0.2721056 , 0.20295432, 0.21681568, 0.21564302,
#        0.19016359, 0.16601879, 0.22535147, 0.16718173])

# %% [markdown]
# Doing the experiments at segment level
